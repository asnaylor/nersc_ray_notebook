# %% [markdown]
# # PyTorch MNIST Example: Ray + Horovod
#
# ----
#
# We are going to run a simple PyTorch MNIST Example. We will train the model distributed using horovod on a Ray Cluster. We are following the code in this example https://docs.ray.io/en/latest/train/examples/horovod/horovod_example.html
#
#
# ## Setup
#
# Execute these command in terminal/shell to install the jupyter kernel in your user environment:
# ```bash
# source setup.sh
# ```
#
# Then select the kernel which uses `nersc/pytorch:ngc-22.09-v0` shifter image.

# %% [markdown]
# ## Step 1: Start the Ray cluster in the background
#
#
# **[Dev note]**: Current this is an `sbatch` submission on shared-cpu in JupyterHub but might be better if running in the Jupyter-qos with srun instead.
#
#
# Open terminal and execute:
# ```bash
# source scripts/submit_ray_cluster.sh
# ```
#
# Change parameters in `scripts/submit_ray_cluster.sh` to change the job configuration.

# %%
# Check job log
# !cat logs/*.log
# Out:
# cat: 'logs/*.log': No such file or directory

# %% [markdown]
# ## Step 2: Connect to the Cluster

# %%
import ray

from utility import get_ray_cluster_address, cluster_summary

cluster_address = get_ray_cluster_address()

# %%
ray.init(cluster_address)
# Out:
# ClientContext(dashboard_url='', python_version='3.8.13', ray_version='2.0.0', ray_commit='cba26cc83f6b5b8a2ff166594a65cb74c0ec8740', protocol_version='2022-07-24', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x7fa4f4c08790>)

# %%
cluster_summary()
# Out:
# Cluster Summary
# ---------------
# Nodes: 2
# CPU:   256
# GPU:   8
# RAM:   315.08 GB

# %% [markdown]
# ## Step 3: Setup Model

# %%
import argparse
import os

import horovod.torch as hvd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data.distributed
from filelock import FileLock
from torchvision import datasets, transforms

import ray
from ray.air import session
from ray.train.horovod import HorovodTrainer
from ray.air.config import ScalingConfig

# %%
def metric_average(val, name):
    tensor = torch.tensor(val)
    avg_tensor = hvd.allreduce(tensor, name=name)
    return avg_tensor.item()


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def setup(config):
    data_dir = config.get("data_dir", None)
    seed = config.get("seed", 42)
    batch_size = config.get("batch_size", 64)
    use_adasum = config.get("use_adasum", False)
    lr = config.get("lr", 0.01)
    momentum = config.get("momentum", 0.5)
    use_cuda = config.get("use_cuda", False)

    # Horovod: initialize library.
    hvd.init()
    torch.manual_seed(seed)

    if use_cuda:
        # Horovod: pin GPU to local rank.
        torch.cuda.set_device(hvd.local_rank())
        torch.cuda.manual_seed(seed)

    # Horovod: limit # of CPU threads to be used per worker.
    torch.set_num_threads(1)

    kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}
    data_dir = data_dir or "~/data"
    with FileLock(os.path.expanduser("~/.horovod_lock")):
        train_dataset = datasets.MNIST(
            data_dir,
            train=True,
            download=True,
            transform=transforms.Compose(
                [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
            ),
        )
    # Horovod: use DistributedSampler to partition the training data.
    train_sampler = torch.utils.data.distributed.DistributedSampler(
        train_dataset, num_replicas=hvd.size(), rank=hvd.rank()
    )
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler, **kwargs
    )

    model = Net()

    # By default, Adasum doesn't need scaling up learning rate.
    lr_scaler = hvd.size() if not use_adasum else 1

    if use_cuda:
        # Move model to GPU.
        model.cuda()
        # If using GPU Adasum allreduce, scale learning rate by local_size.
        if use_adasum and hvd.nccl_built():
            lr_scaler = hvd.local_size()

    # Horovod: scale learning rate by lr_scaler.
    optimizer = optim.SGD(model.parameters(), lr=lr * lr_scaler, momentum=momentum)

    # Horovod: wrap optimizer with DistributedOptimizer.
    optimizer = hvd.DistributedOptimizer(
        optimizer,
        named_parameters=model.named_parameters(),
        op=hvd.Adasum if use_adasum else hvd.Average,
    )

    return model, optimizer, train_loader, train_sampler

# %%
def train_epoch(
    model, optimizer, train_sampler, train_loader, epoch, log_interval, use_cuda
):
    loss = None
    model.train()
    # Horovod: set epoch to sampler for shuffling.
    train_sampler.set_epoch(epoch)
    for batch_idx, (data, target) in enumerate(train_loader):
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            # Horovod: use train_sampler to determine the number of
            # examples in this worker's partition.
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(data),
                    len(train_sampler),
                    100.0 * batch_idx / len(train_loader),
                    loss.item(),
                )
            )
    return loss.item() if loss else None

# %%
def train_func(config):
    num_epochs = config.get("num_epochs", 10)
    log_interval = config.get("log_interval", 10)
    use_cuda = config.get("use_cuda", False)

    model, optimizer, train_loader, train_sampler = setup(config)

    for epoch in range(num_epochs):
        loss = train_epoch(
            model, optimizer, train_sampler, train_loader, epoch, log_interval, use_cuda
        )
        session.report(dict(loss=loss))

# %% [markdown]
# ## Step 4: Train Model

# %%
import os

P_SCRATCH = os.getenv('SCRATCH')

num_workers = 8
use_cuda = True

kwargs = {
        "data_dir": os.path.join(P_SCRATCH, 'MNIST'),
        "seed": 42,
        "use_cuda": use_cuda,
        "batch_size": 64,
        "use_adasum": False,
        "lr": 0.01,
        "momentum": 0.5,
        "num_epochs": 50, #5
        "log_interval": 20,
    }

# %%
trainer = HorovodTrainer(
        train_func,
        train_loop_config=kwargs,
        scaling_config=ScalingConfig(use_gpu=use_cuda, num_workers=num_workers),
    )
results = trainer.fit()
print(results.metrics)
# Out:
# (TunerInternal pid=55624) 2023-02-03 23:54:00,106	WARNING trial_runner.py:328 -- The maximum number of pending trials has been automatically set to the number of available cluster CPUs, which is high (281 CPUs/pending trials). If you're running an experiment with a large number of trials, this could lead to scheduling overhead. In this case, consider setting the `TUNE_MAX_PENDING_TRIALS_PG` environment variable to the desired maximum number of concurrent trials.
# (TunerInternal pid=55624) == Status ==
# (TunerInternal pid=55624) Current time: 2023-02-03 23:54:04 (running for 00:00:04.20)
# (TunerInternal pid=55624) Memory usage on this node: 36.0/251.3 GiB
# (TunerInternal pid=55624) Using FIFO scheduling algorithm.
# (TunerInternal pid=55624) Resources requested: 1.0/256 CPUs, 8.0/8 GPUs, 0.0/315.08 GiB heap, 0.0/139.03 GiB objects (0.0/2.0 accelerator_type:A100)
# (TunerInternal pid=55624) Result logdir: /global/homes/a/asnaylor/ray_results/HorovodTrainer_2023-02-03_23-54-00
# (TunerInternal pid=55624) Number of trials: 1/1 (1 RUNNING)
# (TunerInternal pid=55624) +----------------------------+----------+------------------+
# (TunerInternal pid=55624) | Trial name                 | status   | loc              |
# (TunerInternal pid=55624) |----------------------------+----------+------------------|
# (TunerInternal pid=55624) | HorovodTrainer_078cb_00000 | RUNNING  | 10.249.4.75:9294 |
# (TunerInternal pid=55624) +----------------------------+----------+------------------+
# (TunerInternal pid=55624)
# (TunerInternal pid=55624)
# (TunerInternal pid=55624) == Status ==
# (TunerInternal pid=55624) Current time: 2023-02-03 23:54:09 (running for 00:00:09.20)
# (TunerInternal pid=55624) Memory usage on this node: 36.3/251.3 GiB
# (TunerInternal pid=55624) Using FIFO scheduling algorithm.
# (TunerInternal pid=55624) Resources requested: 1.0/256 CPUs, 8.0/8 GPUs, 0.0/315.08 GiB heap, 0.0/139.03 GiB objects (0.0/2.0 accelerator_type:A100)
# (TunerInternal pid=55624) Result logdir: /global/homes/a/asnaylor/ray_results/HorovodTrainer_2023-02-03_23-54-00
# (TunerInternal pid=55624) Number of trials: 1/1 (1 RUNNING)
# (TunerInternal pid=55624) +----------------------------+----------+------------------+
# (TunerInternal pid=55624) | Trial name                 | status   | loc              |
# (TunerInternal pid=55624) |----------------------------+----------+------------------|
# (TunerInternal pid=55624) | HorovodTrainer_078cb_00000 | RUNNING  | 10.249.4.75:9294 |
# (TunerInternal pid=55624) +----------------------------+----------+------------------+
# (TunerInternal pid=55624)
# (TunerInternal pid=55624)
# (TunerInternal pid=55624) == Status ==
# (TunerInternal pid=55624) Current time: 2023-02-03 23:54:14 (running for 00:00:14.21)
# (TunerInternal pid=55624) Memory usage on this node: 36.6/251.3 GiB
# (TunerInternal pid=55624) Using FIFO scheduling algorithm.
# (TunerInternal pid=55624) Resources requested: 1.0/256 CPUs, 8.0/8 GPUs, 0.0/315.08 GiB heap, 0.0/139.03 GiB objects (0.0/2.0 accelerator_type:A100)
# (TunerInternal pid=55624) Result logdir: /global/homes/a/asnaylor/ray_results/HorovodTrainer_2023-02-03_23-54-00
# (TunerInternal pid=55624) Number of trials: 1/1 (1 RUNNING)
# (TunerInternal pid=55624) +----------------------------+----------+------------------+
# (TunerInternal pid=55624) | Trial name                 | status   | loc              |
# (TunerInternal pid=55624) |----------------------------+----------+------------------|
# (TunerInternal pid=55624) | HorovodTrainer_078cb_00000 | RUNNING  | 10.249.4.75:9294 |
# (TunerInternal pid=55624) +----------------------------+----------+------------------+
# (TunerInternal pid=55624)
# (TunerInternal pid=55624)
# (RayTrainWorker pid=58287) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=11280, ip=128.55.64.255) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=11276, ip=128.55.64.255) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=11275, ip=128.55.64.255) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=58286) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=58284) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=58285) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=11271, ip=128.55.64.255) /tmp/ipykernel_217862/1202429123.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.318332
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.303264
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.349172
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.316720
# (RayTrainWorker pid=58286) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.326882
# (RayTrainWorker pid=58284) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.325468
# (RayTrainWorker pid=58287) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.285996
# (RayTrainWorker pid=58285) Train Epoch: 0 [0/7500 (0%)]	Loss: 2.355100
# (RayTrainWorker pid=58286) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.044160
# (RayTrainWorker pid=58284) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.070380
# (RayTrainWorker pid=58287) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.022024
# (RayTrainWorker pid=58285) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.021193
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.104462
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.031472
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.068565
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 0 [1280/7500 (17%)]	Loss: 2.087673
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 0 [2560/7500 (34%)]	Loss: 0.924854
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 0 [2560/7500 (34%)]	Loss: 1.196409
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 0 [2560/7500 (34%)]	Loss: 1.014628
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 0 [2560/7500 (34%)]	Loss: 1.097209
# (RayTrainWorker pid=58286) Train Epoch: 0 [2560/7500 (34%)]	Loss: 0.992247
# (RayTrainWorker pid=58284) Train Epoch: 0 [2560/7500 (34%)]	Loss: 1.123422
# (RayTrainWorker pid=58287) Train Epoch: 0 [2560/7500 (34%)]	Loss: 1.006717
# (RayTrainWorker pid=58285) Train Epoch: 0 [2560/7500 (34%)]	Loss: 1.042882
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.811821
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.822748
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.638841
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.517891
# (RayTrainWorker pid=58286) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.788332
# (RayTrainWorker pid=58284) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.737849
# (RayTrainWorker pid=58287) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.524725
# (RayTrainWorker pid=58285) Train Epoch: 0 [3840/7500 (51%)]	Loss: 0.593540
# (RayTrainWorker pid=58286) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.895669
# (RayTrainWorker pid=58284) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.404553
# (RayTrainWorker pid=58287) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.542281
# (RayTrainWorker pid=58285) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.453997
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.577837
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.579001
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.570221
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 0 [5120/7500 (68%)]	Loss: 0.828048
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.454535
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.341858
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.328154
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.570119
# (RayTrainWorker pid=58286) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.356670
# (RayTrainWorker pid=58284) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.401686
# (RayTrainWorker pid=58287) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.547680
# (RayTrainWorker pid=58285) Train Epoch: 0 [6400/7500 (85%)]	Loss: 0.519127
# (TunerInternal pid=55624) Result for HorovodTrainer_078cb_00000:
# (TunerInternal pid=55624)   _time_this_iter_s: 7.078815460205078
# (TunerInternal pid=55624)   _timestamp: 1675468458
# (TunerInternal pid=55624)   _training_iteration: 1
# (TunerInternal pid=55624)   date: 2023-02-03_23-54-18
# (TunerInternal pid=55624)   done: false
# (TunerInternal pid=55624)   experiment_id: 6ede253bc04341c0b40ed61f6b7b2d6e
# (TunerInternal pid=55624)   hostname: nid001033
# (TunerInternal pid=55624)   iterations_since_restore: 1
# (TunerInternal pid=55624)   loss: 0.6732971668243408
# (TunerInternal pid=55624)   node_ip: 10.249.4.75
# (TunerInternal pid=55624)   pid: 9294
# (TunerInternal pid=55624)   time_since_restore: 13.968108654022217
# (TunerInternal pid=55624)   time_this_iter_s: 13.968108654022217
# (TunerInternal pid=55624)   time_total_s: 13.968108654022217
# (TunerInternal pid=55624)   timestamp: 1675468458
# (TunerInternal pid=55624)   timesteps_since_restore: 0
# (TunerInternal pid=55624)   training_iteration: 1
# (TunerInternal pid=55624)   trial_id: 078cb_00000
# (TunerInternal pid=55624)   warmup_time: 0.003492116928100586
# (TunerInternal pid=55624)
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.676523
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.408431
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.432727
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.404862
# (RayTrainWorker pid=58286) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.705542
# (RayTrainWorker pid=58284) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.620490
# (RayTrainWorker pid=58287) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.532989
# (RayTrainWorker pid=58285) Train Epoch: 1 [0/7500 (0%)]	Loss: 0.674679
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.343103
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.398285
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.430890
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.414443
# (RayTrainWorker pid=58286) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.413060
# (RayTrainWorker pid=58284) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.492899
# (RayTrainWorker pid=58287) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.344627
# (RayTrainWorker pid=58285) Train Epoch: 1 [1280/7500 (17%)]	Loss: 0.460756
# (RayTrainWorker pid=58286) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.555866
# (RayTrainWorker pid=58284) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.436697
# (RayTrainWorker pid=58287) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.448793
# (RayTrainWorker pid=58285) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.633426
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.436144
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.391200
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.504736
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 1 [2560/7500 (34%)]	Loss: 0.478835
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.215099
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.499018
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.280439
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.354298
# (RayTrainWorker pid=58286) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.514807
# (RayTrainWorker pid=58284) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.257697
# (RayTrainWorker pid=58287) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.666481
# (RayTrainWorker pid=58285) Train Epoch: 1 [3840/7500 (51%)]	Loss: 0.335038
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.259021
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.439249
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.346815
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.288436
# (RayTrainWorker pid=58286) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.332487
# (RayTrainWorker pid=58284) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.430850
# (RayTrainWorker pid=58287) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.370597
# (RayTrainWorker pid=58285) Train Epoch: 1 [5120/7500 (68%)]	Loss: 0.415374
# (RayTrainWorker pid=58286) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.276510
# (RayTrainWorker pid=58284) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.308773
# (RayTrainWorker pid=58287) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.518150
# (RayTrainWorker pid=58285) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.550367
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.315211
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.326890
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.151722
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 1 [6400/7500 (85%)]	Loss: 0.584043
# (TunerInternal pid=55624) == Status ==
# (TunerInternal pid=55624) Current time: 2023-02-03 23:54:19 (running for 00:00:19.23)
# (TunerInternal pid=55624) Memory usage on this node: 38.9/251.3 GiB
# (TunerInternal pid=55624) Using FIFO scheduling algorithm.
# (TunerInternal pid=55624) Resources requested: 1.0/256 CPUs, 8.0/8 GPUs, 0.0/315.08 GiB heap, 0.0/139.03 GiB objects (0.0/2.0 accelerator_type:A100)
# (TunerInternal pid=55624) Result logdir: /global/homes/a/asnaylor/ray_results/HorovodTrainer_2023-02-03_23-54-00
# (TunerInternal pid=55624) Number of trials: 1/1 (1 RUNNING)
# (TunerInternal pid=55624) +----------------------------+----------+------------------+--------+------------------+-----------+--------------+---------------------+
# (TunerInternal pid=55624) | Trial name                 | status   | loc              |   iter |   total time (s) |      loss |   _timestamp |   _time_this_iter_s |
# (TunerInternal pid=55624) |----------------------------+----------+------------------+--------+------------------+-----------+--------------+---------------------|
# (TunerInternal pid=55624) | HorovodTrainer_078cb_00000 | RUNNING  | 10.249.4.75:9294 |      2 |          15.0266 | 0.0388381 |   1675468459 |              1.0588 |
# (TunerInternal pid=55624) +----------------------------+----------+------------------+--------+------------------+-----------+--------------+---------------------+
# (TunerInternal pid=55624)
# (TunerInternal pid=55624)
# (RayTrainWorker pid=58286) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.377558
# (RayTrainWorker pid=58284) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.403937
# (RayTrainWorker pid=58287) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.316389
# (RayTrainWorker pid=58285) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.340112
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.295868
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.289212
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.208595
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 2 [0/7500 (0%)]	Loss: 0.315193
# (RayTrainWorker pid=58286) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.390815
# (RayTrainWorker pid=58284) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.437346
# (RayTrainWorker pid=58287) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.375325
# (RayTrainWorker pid=58285) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.433509
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.315011
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.209374
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.362466
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 2 [1280/7500 (17%)]	Loss: 0.615957
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.399894
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.417614
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.235357
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.367546
# (RayTrainWorker pid=58286) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.279994
# (RayTrainWorker pid=58284) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.371752
# (RayTrainWorker pid=58287) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.399257
# (RayTrainWorker pid=58285) Train Epoch: 2 [2560/7500 (34%)]	Loss: 0.145891
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.242731
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.348258
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.304687
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.426765
# (RayTrainWorker pid=58286) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.265978
# (RayTrainWorker pid=58284) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.358983
# (RayTrainWorker pid=58287) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.273818
# (RayTrainWorker pid=58285) Train Epoch: 2 [3840/7500 (51%)]	Loss: 0.225042
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.367490
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.213827
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.666342
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.364121
# (RayTrainWorker pid=58286) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.233200
# (RayTrainWorker pid=58284) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.499814
# (RayTrainWorker pid=58287) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.238961
# (RayTrainWorker pid=58285) Train Epoch: 2 [5120/7500 (68%)]	Loss: 0.206859
# (RayTrainWorker pid=58286) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.339861
# (RayTrainWorker pid=58284) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.229851
# (RayTrainWorker pid=58287) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.275805
# (RayTrainWorker pid=58285) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.216998
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.154508
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.230587
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.182802
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 2 [6400/7500 (85%)]	Loss: 0.309370
# (RayTrainWorker pid=58286) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.238081
# (RayTrainWorker pid=58284) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.238588
# (RayTrainWorker pid=58287) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.124639
# (RayTrainWorker pid=58285) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.304451
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.391423
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.302745
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.432281
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 3 [0/7500 (0%)]	Loss: 0.205489
# (RayTrainWorker pid=58286) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.232292
# (RayTrainWorker pid=58284) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.424724
# (RayTrainWorker pid=58287) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.181359
# (RayTrainWorker pid=58285) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.274083
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.255358
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.255895
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.268189
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 3 [1280/7500 (17%)]	Loss: 0.227594
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.150372
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.173317
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.359835
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.113956
# (RayTrainWorker pid=58286) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.109286
# (RayTrainWorker pid=58284) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.482108
# (RayTrainWorker pid=58287) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.184606
# (RayTrainWorker pid=58285) Train Epoch: 3 [2560/7500 (34%)]	Loss: 0.177294
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.384039
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.332282
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.169984
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.285468
# (RayTrainWorker pid=58286) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.356167
# (RayTrainWorker pid=58284) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.261818
# (RayTrainWorker pid=58287) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.222322
# (RayTrainWorker pid=58285) Train Epoch: 3 [3840/7500 (51%)]	Loss: 0.436219
# (RayTrainWorker pid=58286) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.314383
# (RayTrainWorker pid=58284) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.339290
# (RayTrainWorker pid=58287) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.305763
# (RayTrainWorker pid=58285) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.269225
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.152057
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.135442
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.359706
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 3 [5120/7500 (68%)]	Loss: 0.284083
# (RayTrainWorker pid=58286) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.162760
# (RayTrainWorker pid=58284) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.183390
# (RayTrainWorker pid=58287) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.220478
# (RayTrainWorker pid=58285) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.203871
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.360495
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.276149
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.169806
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 3 [6400/7500 (85%)]	Loss: 0.119408
# (RayTrainWorker pid=58286) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.331945
# (RayTrainWorker pid=58284) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.143622
# (RayTrainWorker pid=58287) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.282254
# (RayTrainWorker pid=58285) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.211752
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.238970
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.254975
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.230110
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 4 [0/7500 (0%)]	Loss: 0.246837
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.095530
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.365262
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.149908
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.276549
# (RayTrainWorker pid=58286) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.232128
# (RayTrainWorker pid=58284) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.221793
# (RayTrainWorker pid=58287) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.373209
# (RayTrainWorker pid=58285) Train Epoch: 4 [1280/7500 (17%)]	Loss: 0.138508
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.281491
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.254225
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.434032
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.514255
# (RayTrainWorker pid=58286) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.462214
# (RayTrainWorker pid=58284) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.233149
# (RayTrainWorker pid=58287) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.211175
# (RayTrainWorker pid=58285) Train Epoch: 4 [2560/7500 (34%)]	Loss: 0.616397
# (RayTrainWorker pid=58286) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.151888
# (RayTrainWorker pid=58284) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.287559
# (RayTrainWorker pid=58287) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.116602
# (RayTrainWorker pid=58285) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.216333
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.342895
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.280347
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.153243
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 4 [3840/7500 (51%)]	Loss: 0.279784
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.135993
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.148977
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.192287
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.261428
# (RayTrainWorker pid=58286) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.231666
# (RayTrainWorker pid=58284) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.523979
# (RayTrainWorker pid=58287) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.321159
# (RayTrainWorker pid=58285) Train Epoch: 4 [5120/7500 (68%)]	Loss: 0.342782
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.233316
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.224664
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.282001
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.325044
# (RayTrainWorker pid=58286) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.186993
# (RayTrainWorker pid=58284) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.200063
# (RayTrainWorker pid=58287) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.255164
# (RayTrainWorker pid=58285) Train Epoch: 4 [6400/7500 (85%)]	Loss: 0.148867
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.182884
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.302157
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.175616
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.220297
# (RayTrainWorker pid=58286) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.094869
# (RayTrainWorker pid=58284) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.244788
# (RayTrainWorker pid=58287) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.256644
# (RayTrainWorker pid=58285) Train Epoch: 5 [0/7500 (0%)]	Loss: 0.157662
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.176901
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.309981
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.264132
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.157023
# (RayTrainWorker pid=58286) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.128982
# (RayTrainWorker pid=58284) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.164474
# (RayTrainWorker pid=58287) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.284960
# (RayTrainWorker pid=58285) Train Epoch: 5 [1280/7500 (17%)]	Loss: 0.136645
# (RayTrainWorker pid=58286) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.180272
# (RayTrainWorker pid=58284) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.394122
# (RayTrainWorker pid=58287) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.145803
# (RayTrainWorker pid=58285) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.240730
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.210861
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.186301
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.143172
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 5 [2560/7500 (34%)]	Loss: 0.105153
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.272264
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.172844
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.315325
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.222314
# (RayTrainWorker pid=58286) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.328453
# (RayTrainWorker pid=58284) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.161438
# (RayTrainWorker pid=58287) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.135547
# (RayTrainWorker pid=58285) Train Epoch: 5 [3840/7500 (51%)]	Loss: 0.250116
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.444178
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.235611
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.360546
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.139614
# (RayTrainWorker pid=58286) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.245415
# (RayTrainWorker pid=58284) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.301190
# (RayTrainWorker pid=58287) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.223689
# (RayTrainWorker pid=58285) Train Epoch: 5 [5120/7500 (68%)]	Loss: 0.258596
# (RayTrainWorker pid=58286) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.218306
# (RayTrainWorker pid=58284) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.190952
# (RayTrainWorker pid=58287) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.214350
# (RayTrainWorker pid=58285) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.167905
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.244161
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.183446
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.280574
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 5 [6400/7500 (85%)]	Loss: 0.249561
# (TunerInternal pid=55624) Result for HorovodTrainer_078cb_00000:
# (TunerInternal pid=55624)   _time_this_iter_s: 1.0868847370147705
# (TunerInternal pid=55624)   _timestamp: 1675468463
# (TunerInternal pid=55624)   _training_iteration: 6
# (TunerInternal pid=55624)   date: 2023-02-03_23-54-23
# (TunerInternal pid=55624)   done: false
# (TunerInternal pid=55624)   experiment_id: 6ede253bc04341c0b40ed61f6b7b2d6e
# (TunerInternal pid=55624)   hostname: nid001033
# (TunerInternal pid=55624)   iterations_since_restore: 6
# (TunerInternal pid=55624)   loss: 0.19555418193340302
# (TunerInternal pid=55624)   node_ip: 10.249.4.75
# (TunerInternal pid=55624)   pid: 9294
# (TunerInternal pid=55624)   time_since_restore: 19.430194854736328
# (TunerInternal pid=55624)   time_this_iter_s: 1.0793588161468506
# (TunerInternal pid=55624)   time_total_s: 19.430194854736328
# (TunerInternal pid=55624)   timestamp: 1675468463
# (TunerInternal pid=55624)   timesteps_since_restore: 0
# (TunerInternal pid=55624)   training_iteration: 6
# (TunerInternal pid=55624)   trial_id: 078cb_00000
# (TunerInternal pid=55624)   warmup_time: 0.003492116928100586
# (TunerInternal pid=55624)
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.265960
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.240610
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.144172
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.336148
# (RayTrainWorker pid=58286) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.316825
# (RayTrainWorker pid=58284) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.130659
# (RayTrainWorker pid=58287) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.208666
# (RayTrainWorker pid=58285) Train Epoch: 6 [0/7500 (0%)]	Loss: 0.171187
# (RayTrainWorker pid=58286) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.241971
# (RayTrainWorker pid=58284) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.364356
# (RayTrainWorker pid=58287) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.195080
# (RayTrainWorker pid=58285) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.189926
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.152191
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.308186
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.217346
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 6 [1280/7500 (17%)]	Loss: 0.090146
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.224789
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.228872
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.208692
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.201219
# (RayTrainWorker pid=58286) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.291997
# (RayTrainWorker pid=58284) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.244563
# (RayTrainWorker pid=58287) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.173003
# (RayTrainWorker pid=58285) Train Epoch: 6 [2560/7500 (34%)]	Loss: 0.117031
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.152634
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.295625
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.229257
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.257706
# (RayTrainWorker pid=58286) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.165235
# (RayTrainWorker pid=58284) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.113624
# (RayTrainWorker pid=58287) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.086853
# (RayTrainWorker pid=58285) Train Epoch: 6 [3840/7500 (51%)]	Loss: 0.169613
# (RayTrainWorker pid=58286) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.093084
# (RayTrainWorker pid=58284) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.183671
# (RayTrainWorker pid=58287) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.401855
# (RayTrainWorker pid=58285) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.320463
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.150660
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.247142
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.355553
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 6 [5120/7500 (68%)]	Loss: 0.227925
# (RayTrainWorker pid=58286) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.202137
# (RayTrainWorker pid=58284) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.336061
# (RayTrainWorker pid=58287) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.162861
# (RayTrainWorker pid=58285) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.116448
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.366845
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.208811
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.110198
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 6 [6400/7500 (85%)]	Loss: 0.133197
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.212073
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.098061
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.073995
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.159077
# (TunerInternal pid=55624) == Status ==
# (TunerInternal pid=55624) Current time: 2023-02-03 23:54:24 (running for 00:00:24.72)
# (TunerInternal pid=55624) Memory usage on this node: 39.1/251.3 GiB
# (TunerInternal pid=55624) Using FIFO scheduling algorithm.
# (TunerInternal pid=55624) Resources requested: 1.0/256 CPUs, 8.0/8 GPUs, 0.0/315.08 GiB heap, 0.0/139.03 GiB objects (0.0/2.0 accelerator_type:A100)
# (TunerInternal pid=55624) Result logdir: /global/homes/a/asnaylor/ray_results/HorovodTrainer_2023-02-03_23-54-00
# (TunerInternal pid=55624) Number of trials: 1/1 (1 RUNNING)
# (TunerInternal pid=55624) +----------------------------+----------+------------------+--------+------------------+----------+--------------+---------------------+
# (TunerInternal pid=55624) | Trial name                 | status   | loc              |   iter |   total time (s) |     loss |   _timestamp |   _time_this_iter_s |
# (TunerInternal pid=55624) |----------------------------+----------+------------------+--------+------------------+----------+--------------+---------------------|
# (TunerInternal pid=55624) | HorovodTrainer_078cb_00000 | RUNNING  | 10.249.4.75:9294 |      7 |           20.514 | 0.222668 |   1675468464 |             1.08209 |
# (TunerInternal pid=55624) +----------------------------+----------+------------------+--------+------------------+----------+--------------+---------------------+
# (TunerInternal pid=55624)
# (TunerInternal pid=55624)
# (RayTrainWorker pid=58286) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.159260
# (RayTrainWorker pid=58284) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.192561
# (RayTrainWorker pid=58287) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.408820
# (RayTrainWorker pid=58285) Train Epoch: 7 [0/7500 (0%)]	Loss: 0.278273
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.123959
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.187883
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.175497
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.163125
# (RayTrainWorker pid=58286) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.161185
# (RayTrainWorker pid=58284) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.216452
# (RayTrainWorker pid=58287) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.205775
# (RayTrainWorker pid=58285) Train Epoch: 7 [1280/7500 (17%)]	Loss: 0.197830
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.268535
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.200819
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.083155
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.177853
# (RayTrainWorker pid=58286) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.131698
# (RayTrainWorker pid=58284) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.106689
# (RayTrainWorker pid=58287) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.153941
# (RayTrainWorker pid=58285) Train Epoch: 7 [2560/7500 (34%)]	Loss: 0.153151
# (RayTrainWorker pid=58286) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.072718
# (RayTrainWorker pid=58284) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.151571
# (RayTrainWorker pid=58287) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.108567
# (RayTrainWorker pid=58285) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.136214
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.268727
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.458376
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.271428
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 7 [3840/7500 (51%)]	Loss: 0.197556
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.477922
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.172332
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.276113
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.273636
# (RayTrainWorker pid=58286) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.114007
# (RayTrainWorker pid=58284) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.241373
# (RayTrainWorker pid=58287) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.291325
# (RayTrainWorker pid=58285) Train Epoch: 7 [5120/7500 (68%)]	Loss: 0.133377
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.213607
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.164937
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.216163
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.166723
# (RayTrainWorker pid=58286) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.133054
# (RayTrainWorker pid=58284) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.363851
# (RayTrainWorker pid=58287) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.093631
# (RayTrainWorker pid=58285) Train Epoch: 7 [6400/7500 (85%)]	Loss: 0.217022
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.198809
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.168658
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.090581
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.063125
# (RayTrainWorker pid=58286) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.162219
# (RayTrainWorker pid=58284) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.241474
# (RayTrainWorker pid=58287) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.103341
# (RayTrainWorker pid=58285) Train Epoch: 8 [0/7500 (0%)]	Loss: 0.151164
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.341719
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.050041
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.094598
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.098275
# (RayTrainWorker pid=58286) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.228690
# (RayTrainWorker pid=58284) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.093330
# (RayTrainWorker pid=58287) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.083120
# (RayTrainWorker pid=58285) Train Epoch: 8 [1280/7500 (17%)]	Loss: 0.187931
# (RayTrainWorker pid=58286) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.044945
# (RayTrainWorker pid=58284) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.063197
# (RayTrainWorker pid=58287) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.122247
# (RayTrainWorker pid=58285) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.320884
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.252791
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.166005
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.465821
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 8 [2560/7500 (34%)]	Loss: 0.275917
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.262043
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.208039
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.096371
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.294349
# (RayTrainWorker pid=58286) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.135848
# (RayTrainWorker pid=58284) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.097884
# (RayTrainWorker pid=58287) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.077769
# (RayTrainWorker pid=58285) Train Epoch: 8 [3840/7500 (51%)]	Loss: 0.271574
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.148784
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.285015
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.063586
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.071809
# (RayTrainWorker pid=58286) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.153386
# (RayTrainWorker pid=58284) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.111565
# (RayTrainWorker pid=58287) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.051316
# (RayTrainWorker pid=58285) Train Epoch: 8 [5120/7500 (68%)]	Loss: 0.364017
# (RayTrainWorker pid=58286) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.430303
# (RayTrainWorker pid=58284) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.219394
# (RayTrainWorker pid=58287) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.094257
# (RayTrainWorker pid=58285) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.153641
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.194069
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.199359
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.166229
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 8 [6400/7500 (85%)]	Loss: 0.135530
# (RayTrainWorker pid=58286) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.062146
# (RayTrainWorker pid=58284) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.377077
# (RayTrainWorker pid=58287) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.396584
# (RayTrainWorker pid=58285) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.115944
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.066728
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.364656
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.262966
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 9 [0/7500 (0%)]	Loss: 0.210808
# (RayTrainWorker pid=58286) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.102630
# (RayTrainWorker pid=58284) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.137901
# (RayTrainWorker pid=58287) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.323439
# (RayTrainWorker pid=58285) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.235424
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.164593
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.069203
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.282942
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 9 [1280/7500 (17%)]	Loss: 0.084784
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 9 [2560/7500 (34%)]	Loss: 0.255273
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 9 [2560/7500 (34%)]	Loss: 0.039577
# ...
# (RayTrainWorker pid=58287) Train Epoch: 47 [0/7500 (0%)]	Loss: 0.065823
# (RayTrainWorker pid=58285) Train Epoch: 47 [0/7500 (0%)]	Loss: 0.040261
# (RayTrainWorker pid=58286) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.070936
# (RayTrainWorker pid=58284) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.098176
# (RayTrainWorker pid=58287) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.061190
# (RayTrainWorker pid=58285) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.118184
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.086137
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.090698
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.183084
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 47 [1280/7500 (17%)]	Loss: 0.102825
# (RayTrainWorker pid=58286) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.234964
# (RayTrainWorker pid=58284) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.021244
# (RayTrainWorker pid=58287) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.118363
# (RayTrainWorker pid=58285) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.172790
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.082245
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.101281
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.084680
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 47 [2560/7500 (34%)]	Loss: 0.157323
# (RayTrainWorker pid=58286) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.029170
# (RayTrainWorker pid=58284) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.086450
# (RayTrainWorker pid=58287) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.181864
# (RayTrainWorker pid=58285) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.073597
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.028013
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.041497
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.038240
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 47 [3840/7500 (51%)]	Loss: 0.114699
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.092018
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.032641
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.299283
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.112549
# (RayTrainWorker pid=58286) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.099377
# (RayTrainWorker pid=58284) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.367942
# (RayTrainWorker pid=58287) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.058483
# (RayTrainWorker pid=58285) Train Epoch: 47 [5120/7500 (68%)]	Loss: 0.055959
# (RayTrainWorker pid=58286) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.052512
# (RayTrainWorker pid=58284) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.024795
# (RayTrainWorker pid=58287) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.075988
# (RayTrainWorker pid=58285) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.068341
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.092407
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.135428
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.021127
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 47 [6400/7500 (85%)]	Loss: 0.097960
# (RayTrainWorker pid=58286) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.015120
# (RayTrainWorker pid=58284) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.132617
# (RayTrainWorker pid=58287) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.111120
# (RayTrainWorker pid=58285) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.118295
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.225157
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.070578
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.062119
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 48 [0/7500 (0%)]	Loss: 0.062458
# (RayTrainWorker pid=58286) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.114489
# (RayTrainWorker pid=58284) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.139530
# (RayTrainWorker pid=58287) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.134813
# (RayTrainWorker pid=58285) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.069842
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.115142
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.057441
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.112702
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 48 [1280/7500 (17%)]	Loss: 0.038306
# (RayTrainWorker pid=58286) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.112018
# (RayTrainWorker pid=58284) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.105742
# (RayTrainWorker pid=58287) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.071873
# (RayTrainWorker pid=58285) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.190631
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.088462
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.150255
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.028859
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 48 [2560/7500 (34%)]	Loss: 0.088773
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.037711
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.047874
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.042496
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.048763
# (RayTrainWorker pid=58286) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.061231
# (RayTrainWorker pid=58284) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.069274
# (RayTrainWorker pid=58287) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.054822
# (RayTrainWorker pid=58285) Train Epoch: 48 [3840/7500 (51%)]	Loss: 0.028353
# (RayTrainWorker pid=58286) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.182232
# (RayTrainWorker pid=58284) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.072565
# (RayTrainWorker pid=58287) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.039765
# (RayTrainWorker pid=58285) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.069979
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.045305
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.220884
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.037651
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 48 [5120/7500 (68%)]	Loss: 0.366349
# (RayTrainWorker pid=58286) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.074799
# (RayTrainWorker pid=58284) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.112687
# (RayTrainWorker pid=58287) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.042762
# (RayTrainWorker pid=58285) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.055648
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.116947
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.261277
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.309290
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 48 [6400/7500 (85%)]	Loss: 0.064906
# (RayTrainWorker pid=58286) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.154120
# (RayTrainWorker pid=58284) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.079484
# (RayTrainWorker pid=58287) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.158073
# (RayTrainWorker pid=58285) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.066454
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.052598
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.146228
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.086046
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 49 [0/7500 (0%)]	Loss: 0.032040
# (RayTrainWorker pid=58286) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.067828
# (RayTrainWorker pid=58284) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.165958
# (RayTrainWorker pid=58287) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.105503
# (RayTrainWorker pid=58285) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.181791
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.111506
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.065166
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.076965
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 49 [1280/7500 (17%)]	Loss: 0.065283
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.141888
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.102635
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.132410
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.189662
# (RayTrainWorker pid=58286) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.058745
# (RayTrainWorker pid=58284) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.049340
# (RayTrainWorker pid=58287) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.114870
# (RayTrainWorker pid=58285) Train Epoch: 49 [2560/7500 (34%)]	Loss: 0.036116
# (RayTrainWorker pid=58286) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.166825
# (RayTrainWorker pid=58284) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.095349
# (RayTrainWorker pid=58287) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.089165
# (RayTrainWorker pid=58285) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.036940
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.107981
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.023718
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.118095
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 49 [3840/7500 (51%)]	Loss: 0.031858
# (RayTrainWorker pid=58286) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.143292
# (RayTrainWorker pid=58284) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.093916
# (RayTrainWorker pid=58287) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.154051
# (RayTrainWorker pid=58285) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.150894
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.188008
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.054452
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.308899
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 49 [5120/7500 (68%)]	Loss: 0.120115
# (RayTrainWorker pid=58286) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.083547
# (RayTrainWorker pid=58284) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.122269
# (RayTrainWorker pid=58287) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.219673
# (RayTrainWorker pid=58285) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.069751
# (RayTrainWorker pid=11275, ip=128.55.64.255) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.076804
# (RayTrainWorker pid=11280, ip=128.55.64.255) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.045598
# (RayTrainWorker pid=11271, ip=128.55.64.255) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.136457
# (RayTrainWorker pid=11276, ip=128.55.64.255) Train Epoch: 49 [6400/7500 (85%)]	Loss: 0.048196
# (RayTrainWorker pid=11276, ip=128.55.64.255) [2023-02-03 23:55:12.557471: E /tmp/pip-install-422qdyel/horovod_c00d8dc7772b41e1ac75987ace25e1c6/horovod/common/operations.cc:697] [2]: Horovod background loop uncaught exception: [/tmp/pip-install-422qdyel/horovod_c00d8dc7772b41e1ac75987ace25e1c6/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [10.249.4.75]:52107
# (TunerInternal pid=55624) 2023-02-03 23:55:13,135	WARNING util.py:220 -- The `process_trial_save` operation took 0.704 s, which may be a performance bottleneck.
# (TunerInternal pid=55624) 2023-02-03 23:55:13,135	WARNING trial_runner.py:950 -- Consider turning off forced head-worker trial checkpoint syncs by setting sync_on_checkpoint=False. Note that this may result in faulty trial restoration if a failure occurs while the checkpoint is being synced from the worker to the head node.
# (TunerInternal pid=55624) Result for HorovodTrainer_078cb_00000:
# (TunerInternal pid=55624)   _time_this_iter_s: 1.106130599975586
# (TunerInternal pid=55624)   _timestamp: 1675468512
# (TunerInternal pid=55624)   _training_iteration: 50
# (TunerInternal pid=55624)   date: 2023-02-03_23-55-12
# (TunerInternal pid=55624)   done: true
# (TunerInternal pid=55624)   experiment_id: 6ede253bc04341c0b40ed61f6b7b2d6e
# (TunerInternal pid=55624)   experiment_tag: '0'
# (TunerInternal pid=55624)   hostname: nid001033
# (TunerInternal pid=55624)   iterations_since_restore: 50
# (TunerInternal pid=55624)   loss: 0.019091863185167313
# (TunerInternal pid=55624)   node_ip: 10.249.4.75
# (TunerInternal pid=55624)   pid: 9294
# (TunerInternal pid=55624)   time_since_restore: 68.00352334976196
# (TunerInternal pid=55624)   time_this_iter_s: 1.1096487045288086
# (TunerInternal pid=55624)   time_total_s: 68.00352334976196
# (TunerInternal pid=55624)   timestamp: 1675468512
# (TunerInternal pid=55624)   timesteps_since_restore: 0
# (TunerInternal pid=55624)   training_iteration: 50
# (TunerInternal pid=55624)   trial_id: 078cb_00000
# (TunerInternal pid=55624)   warmup_time: 0.003492116928100586
# (TunerInternal pid=55624)
# (TunerInternal pid=55624) == Status ==
# (TunerInternal pid=55624) Current time: 2023-02-03 23:55:13 (running for 00:01:13.78)
# (TunerInternal pid=55624) Memory usage on this node: 36.7/251.3 GiB
# (TunerInternal pid=55624) Using FIFO scheduling algorithm.
# (TunerInternal pid=55624) Resources requested: 0/256 CPUs, 0/8 GPUs, 0.0/315.08 GiB heap, 0.0/139.03 GiB objects (0.0/2.0 accelerator_type:A100)
# (TunerInternal pid=55624) Result logdir: /global/homes/a/asnaylor/ray_results/HorovodTrainer_2023-02-03_23-54-00
# (TunerInternal pid=55624) Number of trials: 1/1 (1 TERMINATED)
# (TunerInternal pid=55624) +----------------------------+------------+------------------+--------+------------------+-----------+--------------+---------------------+
# (TunerInternal pid=55624) | Trial name                 | status     | loc              |   iter |   total time (s) |      loss |   _timestamp |   _time_this_iter_s |
# (TunerInternal pid=55624) |----------------------------+------------+------------------+--------+------------------+-----------+--------------+---------------------|
# (TunerInternal pid=55624) | HorovodTrainer_078cb_00000 | TERMINATED | 10.249.4.75:9294 |     50 |          68.0035 | 0.0190919 |   1675468512 |             1.10613 |
# (TunerInternal pid=55624) +----------------------------+------------+------------------+--------+------------------+-----------+--------------+---------------------+
# (TunerInternal pid=55624)
# (TunerInternal pid=55624)
# {'loss': 0.019091863185167313, '_timestamp': 1675468512, '_time_this_iter_s': 1.106130599975586, '_training_iteration': 50, 'time_this_iter_s': 1.1096487045288086, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 50, 'trial_id': '078cb_00000', 'experiment_id': '6ede253bc04341c0b40ed61f6b7b2d6e', 'date': '2023-02-03_23-55-12', 'timestamp': 1675468512, 'time_total_s': 68.00352334976196, 'pid': 9294, 'hostname': 'nid001033', 'node_ip': '10.249.4.75', 'config': {}, 'time_since_restore': 68.00352334976196, 'timesteps_since_restore': 0, 'iterations_since_restore': 50, 'warmup_time': 0.003492116928100586, 'experiment_tag': '0'}
# (TunerInternal pid=55624) 2023-02-03 23:55:13,993	INFO tune.py:758 -- Total run time: 73.90 seconds (73.78 seconds for the tuning loop).

# %%
results
# Out:
# Result(metrics={'loss': 0.019091863185167313, '_timestamp': 1675468512, '_time_this_iter_s': 1.106130599975586, '_training_iteration': 50, 'done': True, 'trial_id': '078cb_00000', 'experiment_tag': '0'}, error=None, log_dir=PosixPath('/global/homes/a/asnaylor/ray_results/HorovodTrainer_2023-02-03_23-54-00/HorovodTrainer_078cb_00000_0_2023-02-03_23-54-00'))

# %% [markdown]
# ## Step 5: Explore Training in Tensorboard

# %%
import nersc_tensorboard_helper
# %load_ext tensorboard

# %%
# %tensorboard --logdir $results.log_dir --port 0
# Out:
#       <iframe id="tensorboard-frame-a2ecc9e6b6b410ec" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a2ecc9e6b6b410ec");
#           const url = new URL("/", window.location);
#           const port = 39769;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
nersc_tensorboard_helper.tb_address()
# Out:
# <a href="https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/39769/">https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/39769/</a>

# %% [markdown]
# ### Stop cluster connection and job

# %%
ray.shutdown()

# %% [markdown]
# Excecute this in terminal:
# ```bash
# scancel -u $USER #note this stops all current jobs for the user
# ```
