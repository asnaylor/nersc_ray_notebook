# %% [markdown]
# # NERSC Cluster Deploy Tutorial: Tuning Hyperparameters of a Distributed TensorFlow Model using Ray Train & Tune
#
# 📖 [Back to Table of Contents](../README.md)<br>
# ⬅ [Previous notebook](./ex_01_pytorch_ray_train_tune.ipynb) <br>
# <!-- ➡ [Next notebook](./ex_03_pytorch_ray_hvd.ipynb) <br> -->
#
# ----
#
#
# ## Introduction
#
# We are going to run an example Ray Train & Tune code. This example looks at tunning hyperparameters of a distrbuted TensorFlow Model. This tutorial is following the code in this example:
# https://docs.ray.io/en/latest/train/examples/tf/tune_tensorflow_mnist_example.html
#
# > **Note**:
# > To setup the environment for the notebook, execute on command line: `./setup.sh 2` then select the kernel `tensorflow-2.9.0` in the notebook
#
# This Ray cluster will be setup using the NERSC TensorFlow module and deployed on Perlmutter.

# %%
import sys

# %%
# !{sys.executable} -m pip install --upgrade git+https://github.com/asnaylor/nersc_cluster_deploy.git

# %% [markdown]
# ## Creating Ray Cluster via Jupyter Config Job
#
# To create a ray cluster on NERSC compute nodes, execute the `deploy_ray_cluster` function with your desired slurm sbatch options.

# %%
from nersc_cluster_deploy import deploy_ray_cluster

module_load = 'tensorflow/2.9.0'

rayCluster = deploy_ray_cluster(
    job_setup = f'module load {module_load}'
)
# Out:
# 2023-05-04 13:20:22,609 INFO <Service-Manager> Starting up cluster
# 2023-05-04 13:20:22,648 INFO <RayHead> Starting service
# 2023-05-04 13:20:22,648 DEBUG <RayHead> Running cmd: /bin/bash -c "export RAY_GRAFANA_IFRAME_HOST=https://jupyter.nersc.gov/user/asnaylor/muller-configurable-gpu/proxy/3000; module load tensorflow/2.9.0;srun --nodes=1 --ntasks=1 --cpus-per-task=124 --gpus-per-task=4 -w nid001069  ray start --head --block --port 6379 --num-cpus=124 --num-gpus=4"
# Warning: This is an experimental release of NCCL with an OFI plugin for use with libfabric on Perlmutter.
# In case of issues, please refer to our known issues: https://docs.nersc.gov/current/
# and open a help ticket if your issue is not listed: https://help.nersc.gov/
# 2023-05-04 13:20:25,039	INFO usage_lib.py:435 -- Usage stats collection is disabled.
# 2023-05-04 13:20:25,039	INFO scripts.py:710 -- Local node IP: 128.55.173.50
# 2023-05-04 13:20:28,370	SUCC scripts.py:747 -- --------------------
# 2023-05-04 13:20:28,370	SUCC scripts.py:748 -- Ray runtime started.
# 2023-05-04 13:20:28,370	SUCC scripts.py:749 -- --------------------
# 2023-05-04 13:20:28,370	INFO scripts.py:751 -- Next steps
# 2023-05-04 13:20:28,370	INFO scripts.py:752 -- To connect to this Ray runtime from another node, run
# 2023-05-04 13:20:28,370	INFO scripts.py:755 --   ray start --address='128.55.173.50:6379'
# 2023-05-04 13:20:28,370	INFO scripts.py:771 -- Alternatively, use the following Python code:
# 2023-05-04 13:20:28,370	INFO scripts.py:773 -- import ray
# 2023-05-04 13:20:28,370	INFO scripts.py:777 -- ray.init(address='auto')
# 2023-05-04 13:20:28,370	INFO scripts.py:790 -- To see the status of the cluster, use
# 2023-05-04 13:20:28,370	INFO scripts.py:791 --   ray status
# 2023-05-04 13:20:28,370	INFO scripts.py:794 -- To monitor and debug Ray, view the dashboard at
# 2023-05-04 13:20:28,370	INFO scripts.py:795 --   127.0.0.1:8265
# 2023-05-04 13:20:28,370	INFO scripts.py:801 -- If connection fails, check your firewall settings and network configuration.
# 2023-05-04 13:20:28,370	INFO scripts.py:809 -- To terminate the Ray runtime, run
# 2023-05-04 13:20:28,370	INFO scripts.py:810 --   ray stop
# 2023-05-04 13:20:28,371	INFO scripts.py:888 -- --block
# 2023-05-04 13:20:28,371	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-05-04 13:20:28,371	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2023-05-04 13:20:32,688 INFO <Prometheus> Starting service
# 2023-05-04 13:20:32,688 DEBUG <Prometheus> Running cmd: srun --nodes=1 --ntasks=1 --cpus-per-task=2 --gpus-per-task=0 -w nid001069 shifter --image=prom/prometheus:v2.42.0 --volume=/mscratch/sd/a/asnaylor/ray_cluster/prometheus:/prometheus /bin/prometheus --config.file=/tmp/ray/session_latest/metrics/prometheus/prometheus.yml --storage.tsdb.path=/prometheus
# 2023-05-04 13:20:32,697 INFO <Grafana> Starting service
# 2023-05-04 13:20:32,698 DEBUG <Grafana> Running cmd: srun --nodes=1 --ntasks=1 --cpus-per-task=2 --gpus-per-task=0 -w nid001069 shifter --image=grafana/grafana-oss:9.4.3 --volume=/mscratch/sd/a/asnaylor/ray_cluster/grafana:/grafana --env GF_PATHS_DATA=/grafana --env GF_PATHS_PLUGINS=/grafana/plugins --env GF_SERVER_ROOT_URL=https://jupyter.nersc.gov/user/asnaylor/muller-configurable-gpu/proxy/3000/ --env GF_PATHS_CONFIG=/tmp/ray/session_latest/metrics/grafana/grafana.ini --env GF_PATHS_PROVISIONING=/tmp/ray/session_latest/metrics/grafana/provisioning --entrypoint &
# 2023-05-04 13:20:32,705 INFO <Service-Manager> Cluster startup complete
# Creating Ray workers via srun
# [slurm] starting script...
# Warning: This is an experimental release of NCCL with an OFI plugin for use with libfabric on Perlmutter.
# In case of issues, please refer to our known issues: https://docs.nersc.gov/current/
# and open a help ticket if your issue is not listed: https://help.nersc.gov/
# [slurm] - Starting 2 Ray worker nodes
#     - 0 at nid001072
#     - 1 at nid001073
# ts=2023-05-04T20:20:33.666Z caller=main.go:512 level=info msg="No time or size retention was set so using the default time retention" duration=15d
# ts=2023-05-04T20:20:33.666Z caller=main.go:556 level=info msg="Starting Prometheus Server" mode=server version="(version=2.42.0, branch=HEAD, revision=225c61122d88b01d1f0eaaee0e05b6f3e0567ac0)"
# ts=2023-05-04T20:20:33.666Z caller=main.go:561 level=info build_context="(go=go1.19.5, platform=linux/amd64, user=root@c67d48967507, date=20230201-07:53:32)"
# ts=2023-05-04T20:20:33.666Z caller=main.go:562 level=info host_details="(Linux 5.14.21-150400.24.46_12.0.71-cray_shasta_c #1 SMP Sun Apr 30 16:36:43 UTC 2023 (92112fd) x86_64 nid001069 )"
# ts=2023-05-04T20:20:33.666Z caller=main.go:563 level=info fd_limits="(soft=131072, hard=131072)"
# ts=2023-05-04T20:20:33.666Z caller=main.go:564 level=info vm_limits="(soft=unlimited, hard=unlimited)"
# ts=2023-05-04T20:20:33.670Z caller=web.go:561 level=info component=web msg="Start listening for connections" address=0.0.0.0:9090
# ts=2023-05-04T20:20:33.670Z caller=main.go:993 level=info msg="Starting TSDB ..."
# ts=2023-05-04T20:20:33.672Z caller=tls_config.go:232 level=info component=web msg="Listening on" address=[::]:9090
# ts=2023-05-04T20:20:33.672Z caller=tls_config.go:235 level=info component=web msg="TLS is disabled." http2=false address=[::]:9090
# ts=2023-05-04T20:20:33.673Z caller=dir_locker.go:77 level=warn component=tsdb msg="A lockfile from a previous execution already existed. It was replaced" file=/prometheus/lock
# ts=2023-05-04T20:20:33.680Z caller=head.go:564 level=info component=tsdb msg="Replaying on-disk memory mappable chunks if any"
# ts=2023-05-04T20:20:33.680Z caller=head.go:608 level=info component=tsdb msg="On-disk memory mappable chunks replay completed" duration=7.755µs
# ts=2023-05-04T20:20:33.680Z caller=head.go:614 level=info component=tsdb msg="Replaying WAL, this may take a while"
# ts=2023-05-04T20:20:33.682Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=0 maxSegment=9
# ts=2023-05-04T20:20:33.684Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=1 maxSegment=9
# ts=2023-05-04T20:20:33.686Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=2 maxSegment=9
# ts=2023-05-04T20:20:33.692Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=3 maxSegment=9
# ts=2023-05-04T20:20:33.695Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=4 maxSegment=9
# ts=2023-05-04T20:20:33.697Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=5 maxSegment=9
# ts=2023-05-04T20:20:33.700Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=6 maxSegment=9
# ts=2023-05-04T20:20:33.701Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=7 maxSegment=9
# ts=2023-05-04T20:20:33.779Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=8 maxSegment=9
# ts=2023-05-04T20:20:33.780Z caller=head.go:685 level=info component=tsdb msg="WAL segment loaded" segment=9 maxSegment=9
# ts=2023-05-04T20:20:33.780Z caller=head.go:722 level=info component=tsdb msg="WAL replay completed" checkpoint_replay_duration=267.907µs wal_replay_duration=99.792662ms wbl_replay_duration=201ns total_replay_duration=100.08214ms
# ts=2023-05-04T20:20:33.781Z caller=main.go:1014 level=info fs_type=bd00bd0
# ts=2023-05-04T20:20:33.781Z caller=main.go:1017 level=info msg="TSDB started"
# ts=2023-05-04T20:20:33.781Z caller=main.go:1197 level=info msg="Loading configuration file" filename=/tmp/ray/session_latest/metrics/prometheus/prometheus.yml
# ts=2023-05-04T20:20:33.787Z caller=main.go:1234 level=info msg="Completed loading of configuration file" filename=/tmp/ray/session_latest/metrics/prometheus/prometheus.yml totalDuration=5.703558ms db_storage=812ns remote_storage=1.353µs web_handler=481ns query_engine=652ns scrape=5.488834ms scrape_sd=18.095µs notify=932ns notify_sd=1.924µs rules=1.614µs tracing=6.353µs
# ts=2023-05-04T20:20:33.787Z caller=main.go:978 level=info msg="Server is ready to receive web requests."
# ts=2023-05-04T20:20:33.787Z caller=manager.go:974 level=info component="rule manager" msg="Starting rule manager..."
# logger=settings t=2023-05-04T13:20:34.071154249-07:00 level=info msg="Starting Grafana" version=9.4.3 commit=cf0a135595 branch=HEAD compiled=2023-03-02T12:28:42-08:00
# logger=settings t=2023-05-04T13:20:34.07136202-07:00 level=warn msg="\"sentry\" frontend logging provider is deprecated and will be removed in the next major version. Use \"grafana\" provider instead."
# logger=settings t=2023-05-04T13:20:34.071373011-07:00 level=info msg="Config loaded from" file=/usr/share/grafana/conf/defaults.ini
# logger=settings t=2023-05-04T13:20:34.07137771-07:00 level=info msg="Config loaded from" file=/tmp/ray/session_latest/metrics/grafana/grafana.ini
# logger=settings t=2023-05-04T13:20:34.071380876-07:00 level=info msg="Config overridden from command line" arg="default.paths.data=/grafana"
# logger=settings t=2023-05-04T13:20:34.071383571-07:00 level=info msg="Config overridden from command line" arg="default.paths.logs=/var/log/grafana"
# logger=settings t=2023-05-04T13:20:34.071386156-07:00 level=info msg="Config overridden from command line" arg="default.paths.plugins=/grafana/plugins"
# logger=settings t=2023-05-04T13:20:34.071388681-07:00 level=info msg="Config overridden from command line" arg="default.paths.provisioning=/tmp/ray/session_latest/metrics/grafana/provisioning"
# logger=settings t=2023-05-04T13:20:34.071391577-07:00 level=info msg="Config overridden from command line" arg="default.log.mode=console"
# logger=settings t=2023-05-04T13:20:34.071394422-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_DATA=/grafana"
# logger=settings t=2023-05-04T13:20:34.071397047-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_LOGS=/var/log/grafana"
# logger=settings t=2023-05-04T13:20:34.071399773-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_PLUGINS=/grafana/plugins"
# logger=settings t=2023-05-04T13:20:34.071402398-07:00 level=info msg="Config overridden from Environment variable" var="GF_PATHS_PROVISIONING=/tmp/ray/session_latest/metrics/grafana/provisioning"
# logger=settings t=2023-05-04T13:20:34.071404923-07:00 level=info msg="Config overridden from Environment variable" var="GF_SERVER_ROOT_URL=https://jupyter.nersc.gov/user/asnaylor/muller-configurable-gpu/proxy/3000/"
# logger=settings t=2023-05-04T13:20:34.071407528-07:00 level=info msg="Path Home" path=/usr/share/grafana
# logger=settings t=2023-05-04T13:20:34.071410183-07:00 level=info msg="Path Data" path=/grafana
# logger=settings t=2023-05-04T13:20:34.071412617-07:00 level=info msg="Path Logs" path=/var/log/grafana
# logger=settings t=2023-05-04T13:20:34.071415052-07:00 level=info msg="Path Plugins" path=/grafana/plugins
# logger=settings t=2023-05-04T13:20:34.071417617-07:00 level=info msg="Path Provisioning" path=/tmp/ray/session_latest/metrics/grafana/provisioning
# logger=settings t=2023-05-04T13:20:34.071420402-07:00 level=info msg="App mode production"
# logger=sqlstore t=2023-05-04T13:20:34.071485809-07:00 level=info msg="Connecting to DB" dbtype=sqlite3
# logger=migrator t=2023-05-04T13:20:34.093408143-07:00 level=info msg="Starting DB migrations"
# logger=migrator t=2023-05-04T13:20:34.098486485-07:00 level=info msg="migrations completed" performed=0 skipped=481 duration=501.718µs
# logger=plugin.finder t=2023-05-04T13:20:34.141243255-07:00 level=warn msg="Skipping finding plugins as directory does not exist" path=/usr/share/grafana/plugins-bundled
# logger=secrets t=2023-05-04T13:20:34.14156152-07:00 level=info msg="Envelope encryption state" enabled=true currentprovider=secretKey.v1
# logger=query_data t=2023-05-04T13:20:34.147835971-07:00 level=info msg="Query Service initialization"
# logger=live.push_http t=2023-05-04T13:20:34.162391025-07:00 level=info msg="Live Push Gateway initialization"
# logger=infra.usagestats.collector t=2023-05-04T13:20:34.887567799-07:00 level=info msg="registering usage stat providers" usageStatsProvidersLen=2
# logger=provisioning.plugins t=2023-05-04T13:20:34.966220005-07:00 level=error msg="Failed to read plugin provisioning files from directory" path=/tmp/ray/session_latest/metrics/grafana/provisioning/plugins error="open /tmp/ray/session_latest/metrics/grafana/provisioning/plugins: no such file or directory"
# logger=provisioning.notifiers t=2023-05-04T13:20:34.966240595-07:00 level=error msg="Can't read alert notification provisioning files from directory" path=/tmp/ray/session_latest/metrics/grafana/provisioning/notifiers error="open /tmp/ray/session_latest/metrics/grafana/provisioning/notifiers: no such file or directory"
# logger=provisioning.alerting t=2023-05-04T13:20:34.966253991-07:00 level=error msg="can't read alerting provisioning files from directory" path=/tmp/ray/session_latest/metrics/grafana/provisioning/alerting error="open /tmp/ray/session_latest/metrics/grafana/provisioning/alerting: no such file or directory"
# logger=provisioning.alerting t=2023-05-04T13:20:34.966258119-07:00 level=info msg="starting to provision alerting"
# logger=provisioning.alerting t=2023-05-04T13:20:34.966264431-07:00 level=info msg="finished to provision alerting"
# logger=grafanaStorageLogger t=2023-05-04T13:20:34.966459688-07:00 level=info msg="storage starting"
# logger=ngalert.state.manager t=2023-05-04T13:20:34.96727966-07:00 level=info msg="Warming state cache for startup"
# logger=http.server t=2023-05-04T13:20:34.969690033-07:00 level=info msg="HTTP Server Listen" address=[::]:3000 protocol=http subUrl=/user/asnaylor/muller-configurable-gpu/proxy/3000 socket=
# logger=ngalert.state.manager t=2023-05-04T13:20:34.978114474-07:00 level=info msg="State cache has been initialized" states=0 duration=10.834362ms
# logger=ticker t=2023-05-04T13:20:34.979405325-07:00 level=info msg=starting first_tick=2023-05-04T13:20:40-07:00
# logger=ngalert.multiorg.alertmanager t=2023-05-04T13:20:34.979423851-07:00 level=info msg="starting MultiOrg Alertmanager"
# logger=sqlstore.transactions t=2023-05-04T13:20:35.01175643-07:00 level=info msg="Database locked, sleeping then retrying" error="database is locked" retry=0 code="database is locked"
# [2023-05-04 13:20:36,308 W 65434 65434] global_state_accessor.cc:389: Some processes that the driver needs to connect to have not registered with GCS, so retrying. Have you run 'ray start' on this node?
# [2023-05-04 13:20:36,729 W 13188 13188] global_state_accessor.cc:389: Some processes that the driver needs to connect to have not registered with GCS, so retrying. Have you run 'ray start' on this node?
# 2023-05-04 13:20:36,168	INFO scripts.py:866 -- Local node IP: 10.250.1.90
# 2023-05-04 13:20:37,310	SUCC scripts.py:878 -- --------------------
# 2023-05-04 13:20:37,310	SUCC scripts.py:879 -- Ray runtime started.
# 2023-05-04 13:20:37,310	SUCC scripts.py:880 -- --------------------
# 2023-05-04 13:20:37,310	INFO scripts.py:882 -- To terminate the Ray runtime, run
# 2023-05-04 13:20:37,310	INFO scripts.py:883 --   ray stop
# 2023-05-04 13:20:37,310	INFO scripts.py:888 -- --block
# 2023-05-04 13:20:37,310	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-05-04 13:20:37,310	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# 2023-05-04 13:20:36,600	INFO scripts.py:866 -- Local node IP: 10.250.1.57
# 2023-05-04 13:20:37,731	SUCC scripts.py:878 -- --------------------
# 2023-05-04 13:20:37,731	SUCC scripts.py:879 -- Ray runtime started.
# 2023-05-04 13:20:37,731	SUCC scripts.py:880 -- --------------------
# 2023-05-04 13:20:37,731	INFO scripts.py:882 -- To terminate the Ray runtime, run
# 2023-05-04 13:20:37,731	INFO scripts.py:883 --   ray stop
# 2023-05-04 13:20:37,731	INFO scripts.py:888 -- --block
# 2023-05-04 13:20:37,731	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-05-04 13:20:37,731	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.

# %% [markdown]
# ## Connect to Ray + Grafana dashboards
#
# Go to the website:

# %%
rayCluster.ray_dashboard_url
# Out:
# 'https://jupyter.nersc.gov/user/asnaylor/muller-configurable-gpu/proxy/localhost:8265/'
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:15.580095717-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.123443ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:15.614224362-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.052646ms size=0 referer= handler=/api/live/ws
# logger=live t=2023-05-04T13:21:15.831438451-07:00 level=info msg="Initialized channel handler" channel=grafana/dashboard/uid/rayDefaultDashboard address=grafana/dashboard/uid/rayDefaultDashboard
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:31.481380674-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.092083ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:31.517949639-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.922465ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:31.549829604-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.914871ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:31.663958097-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=23 duration=23.125467ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:31.900910414-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.926002ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:31.933176344-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.70215ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:31.968305441-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.56741ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.006223571-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.166567ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.039119507-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.028339ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.077491052-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.760032ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.111121687-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.46373ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.140562854-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.569213ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.175600995-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.636162ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.207769357-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=23 duration=23.312017ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.238375974-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.864483ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.476765947-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.068326ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.712465768-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.127962ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:32.751484863-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.502335ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:33.29098715-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.979366ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:21:46.986786291-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.046354ms size=0 referer= handler=/api/live/ws

# %% [markdown]
# ## Connect to Ray Cluster

# %%
import ray

if ray.is_initialized:
    ray.shutdown()

ray.init(address='auto')
# Out:
# 2023-05-04 13:22:08,961	INFO worker.py:1364 -- Connecting to existing Ray cluster at address: 128.55.173.50:6379...
# 2023-05-04 13:22:08,967	INFO worker.py:1544 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.9.15', ray_version='2.3.0', ray_commit='cf7a56b4b0b648c324722df7c99c168e92ff0b45', address_info={'node_ip_address': '128.55.173.50', 'raylet_ip_address': '128.55.173.50', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-05-04_13-20-25_077749_61621/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-05-04_13-20-25_077749_61621/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2023-05-04_13-20-25_077749_61621', 'metrics_export_port': 63205, 'gcs_address': '128.55.173.50:6379', 'address': '128.55.173.50:6379', 'dashboard_agent_listen_port': 52365, 'node_id': 'a4f29c78d23f2c902d77997ee91f04ccf14116fab0ac73ad3b4da668'})

# %% [markdown]
# Check all nodes connected to cluster

# %%
from nersc_cluster_deploy.ray import cluster_summary

cluster_summary()
# Out:
# Nodes: 3
# CPU:   380
# GPU:   12
# RAM:   479.44 GB

# %% [markdown]
# ## Setup Tensorflow Model

# %%
from ray import tune
from ray.train.tensorflow import TensorflowTrainer
from ray.air.config import ScalingConfig

from ray.train.examples.tf.tensorflow_mnist_example import train_func
from ray.tune.tune_config import TuneConfig
from ray.tune.tuner import Tuner

# %%
def tune_tensorflow_mnist(
    num_workers: int = 2, num_samples: int = 2, use_gpu: bool = False
):
    trainer = TensorflowTrainer(
        train_loop_per_worker=train_func,
        scaling_config=ScalingConfig(num_workers=num_workers, use_gpu=use_gpu),
    )
    tuner = Tuner(
        trainer,
        tune_config=TuneConfig(num_samples=num_samples, metric="accuracy", mode="max"),
        param_space={
            "train_loop_config": {
                "lr": tune.loguniform(1e-4, 1e-1),
                "batch_size": tune.choice([32, 64, 128]),
                "epochs": 3,
            }
        },
    )
    results = tuner.fit()
    best_accuracy = results.get_best_result().metrics["accuracy"]
    print(f"Best accuracy config: {best_accuracy}")
    return results

# %% [markdown]
# ## Train Model

# %%
node_resources = ray.cluster_resources()
num_workers = int(node_resources['GPU'])
use_gpu = True

num_samples = 2
smoke_test = False

# %%
results = tune_tensorflow_mnist(
            num_workers=num_workers,
            num_samples=num_samples,
            use_gpu=use_gpu,
)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-04 13:23:49</td></tr>
# <tr><td>Running for: </td><td>00:01:20.24        </td></tr>
# <tr><td>Memory:      </td><td>49.3/251.3 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 0/380 CPUs, 0/12 GPUs, 0.0/479.44 GiB heap, 0.0/209.46 GiB objects (0.0/3.0 accelerator_type:A100)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc                </th><th style="text-align: right;">    train_loop_config/ba
# tch_size</th><th style="text-align: right;">  train_loop_config/lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  _timestamp</th></tr>
# </thead>
# <tbody>
# <tr><td>TensorflowTrainer_64592_00000</td><td>TERMINATED</td><td>10.250.1.90:67193  </td><td style="text-align: right;">128</td><td style="text-align: right;">             0.0237213</td><td style="text-align: right;">     3</td><td style="text-align: right;">         34.3788</td><td style="text-align: right;">0.337646</td><td style="text-align: right;">  0.904846</td><td style="text-align: right;">  1683231790</td></tr>
# <tr><td>TensorflowTrainer_64592_00001</td><td>TERMINATED</td><td>128.55.173.50:71652</td><td style="text-align: right;">128</td><td style="text-align: right;">             0.0987073</td><td style="text-align: right;">     3</td><td style="text-align: right;">         27.3244</td><td style="text-align: right;">0.214705</td><td style="text-align: right;">  0.937519</td><td style="text-align: right;">  1683231826</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2023-05-04 13:22:29,237	WARNING trial_runner.py:369 -- The maximum number of pending trials has been automatically set to the number of available cluster CPUs, which is high (418 CPUs/pending trials). If you're running an experiment with a large number of trials, this could lead to scheduling overhead. In this case, consider setting the `TUNE_MAX_PENDING_TRIALS_PG` environment variable to the desired maximum number of concurrent trials.
# (RayTrainWorker pid=67426, ip=128.55.173.52) 2023-05-04 13:22:46.774803: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=67426, ip=128.55.173.52) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=65112) 2023-05-04 13:22:46.757586: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=65112) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=65111) 2023-05-04 13:22:46.724651: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=65111) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=14958, ip=128.55.173.51) 2023-05-04 13:22:46.784227: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=14958, ip=128.55.173.51) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=14959, ip=128.55.173.51) 2023-05-04 13:22:46.783672: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=14959, ip=128.55.173.51) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=67427, ip=128.55.173.52) 2023-05-04 13:22:46.803850: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=67427, ip=128.55.173.52) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=67425, ip=128.55.173.52) 2023-05-04 13:22:46.976659: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=67425, ip=128.55.173.52) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=65113) 2023-05-04 13:22:46.949470: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=65113) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=14960, ip=128.55.173.51) 2023-05-04 13:22:47.012075: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=14960, ip=128.55.173.51) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=65114) 2023-05-04 13:22:47.260114: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=65114) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=67428, ip=128.55.173.52) 2023-05-04 13:22:47.321350: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=67428, ip=128.55.173.52) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=14961, ip=128.55.173.51) 2023-05-04 13:22:47.336669: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (RayTrainWorker pid=14961, ip=128.55.173.51) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (RayTrainWorker pid=65112) 2023-05-04 13:22:48.106563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# (RayTrainWorker pid=65111) 2023-05-04 13:22:48.109974: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# (RayTrainWorker pid=67427, ip=128.55.173.52) 2023-05-04 13:22:48.185004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# (RayTrainWorker pid=67427, ip=128.55.173.52) 2023-05-04 13:22:48.201397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:2/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# (RayTrainWorker pid=67425, ip=128.55.173.52) 2023-05-04 13:22:48.211798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# (RayTrainWorker pid=65114) 2023-05-04 13:22:48.119907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# (RayTrainWorker pid=65114) 2023-05-04 13:22:48.134960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:11/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# (RayTrainWorker pid=65114) 2023-05-04 13:22:48.171437: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65114) 2023-05-04 13:22:48.173739: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65114) 2023-05-04 13:22:48.176420: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://128.55.173.50:50333
# (RayTrainWorker pid=65113) 2023-05-04 13:22:48.121626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# (RayTrainWorker pid=65113) 2023-05-04 13:22:48.135939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:6/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# (RayTrainWorker pid=65113) 2023-05-04 13:22:48.171437: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65113) 2023-05-04 13:22:48.173743: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65113) 2023-05-04 13:22:48.176451: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://128.55.173.50:60515
# (RayTrainWorker pid=65112) 2023-05-04 13:22:48.123622: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:9/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# (RayTrainWorker pid=65112) 2023-05-04 13:22:48.171436: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65112) 2023-05-04 13:22:48.173740: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65112) 2023-05-04 13:22:48.176422: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://128.55.173.50:56681
# (RayTrainWorker pid=65111) 2023-05-04 13:22:48.124354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:10/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# (RayTrainWorker pid=65111) 2023-05-04 13:22:48.171441: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65111) 2023-05-04 13:22:48.173749: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=65111) 2023-05-04 13:22:48.176411: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://128.55.173.50:56421
# (RayTrainWorker pid=67428, ip=128.55.173.52) 2023-05-04 13:22:48.220082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# (RayTrainWorker pid=67428, ip=128.55.173.52) 2023-05-04 13:22:48.235460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:3/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# (RayTrainWorker pid=67428, ip=128.55.173.52) 2023-05-04 13:22:48.255484: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67428, ip=128.55.173.52) 2023-05-04 13:22:48.255600: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67428, ip=128.55.173.52) 2023-05-04 13:22:48.256523: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.90:36315
# (RayTrainWorker pid=67425, ip=128.55.173.52) 2023-05-04 13:22:48.226875: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# (RayTrainWorker pid=67425, ip=128.55.173.52) 2023-05-04 13:22:48.247090: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67425, ip=128.55.173.52) 2023-05-04 13:22:48.248198: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67425, ip=128.55.173.52) 2023-05-04 13:22:48.252829: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.90:45437
# (RayTrainWorker pid=67427, ip=128.55.173.52) 2023-05-04 13:22:48.247094: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67427, ip=128.55.173.52) 2023-05-04 13:22:48.248189: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67427, ip=128.55.173.52) 2023-05-04 13:22:48.252825: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.90:55059
# (RayTrainWorker pid=67426, ip=128.55.173.52) 2023-05-04 13:22:48.225457: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# (RayTrainWorker pid=67426, ip=128.55.173.52) 2023-05-04 13:22:48.240762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:1/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# (RayTrainWorker pid=67426, ip=128.55.173.52) 2023-05-04 13:22:48.261698: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67426, ip=128.55.173.52) 2023-05-04 13:22:48.261790: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=67426, ip=128.55.173.52) 2023-05-04 13:22:48.262351: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.90:40483
# (RayTrainWorker pid=14958, ip=128.55.173.51) 2023-05-04 13:22:48.301834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# (RayTrainWorker pid=14958, ip=128.55.173.51) 2023-05-04 13:22:48.316867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:8/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# (RayTrainWorker pid=14961, ip=128.55.173.51) 2023-05-04 13:22:48.322633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# (RayTrainWorker pid=14960, ip=128.55.173.51) 2023-05-04 13:22:48.323726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# (RayTrainWorker pid=14959, ip=128.55.173.51) 2023-05-04 13:22:48.289026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# (RayTrainWorker pid=14959, ip=128.55.173.51) 2023-05-04 13:22:48.311869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:7/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:82:00.0, compute capability: 8.0
# (RayTrainWorker pid=14958, ip=128.55.173.51) 2023-05-04 13:22:48.354998: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14958, ip=128.55.173.51) 2023-05-04 13:22:48.355793: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14958, ip=128.55.173.51) 2023-05-04 13:22:48.360305: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.57:42251
# (RayTrainWorker pid=14961, ip=128.55.173.51) 2023-05-04 13:22:48.337027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:5/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# (RayTrainWorker pid=14961, ip=128.55.173.51) 2023-05-04 13:22:48.356115: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14961, ip=128.55.173.51) 2023-05-04 13:22:48.356227: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14961, ip=128.55.173.51) 2023-05-04 13:22:48.360332: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.57:58945
# (RayTrainWorker pid=14960, ip=128.55.173.51) 2023-05-04 13:22:48.338399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:worker/replica:0/task:4/device:GPU:0 with 38218 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# (RayTrainWorker pid=14960, ip=128.55.173.51) 2023-05-04 13:22:48.358820: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14960, ip=128.55.173.51) 2023-05-04 13:22:48.358901: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14960, ip=128.55.173.51) 2023-05-04 13:22:48.360299: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.57:38073
# (RayTrainWorker pid=14959, ip=128.55.173.51) 2023-05-04 13:22:48.354999: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14959, ip=128.55.173.51) 2023-05-04 13:22:48.355797: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 10.250.1.90:45437, 1 -> 10.250.1.90:40483, 2 -> 10.250.1.90:55059, 3 -> 10.250.1.90:36315, 4 -> 10.250.1.57:38073, 5 -> 10.250.1.57:58945, 6 -> 128.55.173.50:60515, 7 -> 10.250.1.57:54185, 8 -> 10.250.1.57:42251, 9 -> 128.55.173.50:56681, 10 -> 128.55.173.50:56421, 11 -> 128.55.173.50:50333}
# (RayTrainWorker pid=14959, ip=128.55.173.51) 2023-05-04 13:22:48.360324: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://10.250.1.57:54185
# (RayTrainWorker pid=67428, ip=128.55.173.52) 2023-05-04 13:22:50.592846: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=67428, ip=128.55.173.52) op: "TensorSliceDataset"
# (RayTrainWorker pid=67428, ip=128.55.173.52) input: "Placeholder/_0"
# (RayTrainWorker pid=67428, ip=128.55.173.52) input: "Placeholder/_1"
# (RayTrainWorker pid=67428, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67428, ip=128.55.173.52)   key: "Toutput_types"
# (RayTrainWorker pid=67428, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67428, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67428, ip=128.55.173.52)       type: DT_FLOAT
# (RayTrainWorker pid=67428, ip=128.55.173.52)       type: DT_INT64
# (RayTrainWorker pid=67428, ip=128.55.173.52)     }
# (RayTrainWorker pid=67428, ip=128.55.173.52)   }
# (RayTrainWorker pid=67428, ip=128.55.173.52) }
# (RayTrainWorker pid=67428, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67428, ip=128.55.173.52)   key: "_cardinality"
# (RayTrainWorker pid=67428, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67428, ip=128.55.173.52)     i: 60000
# (RayTrainWorker pid=67428, ip=128.55.173.52)   }
# (RayTrainWorker pid=67428, ip=128.55.173.52) }
# (RayTrainWorker pid=67428, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67428, ip=128.55.173.52)   key: "is_files"
# (RayTrainWorker pid=67428, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67428, ip=128.55.173.52)     b: false
# (RayTrainWorker pid=67428, ip=128.55.173.52)   }
# (RayTrainWorker pid=67428, ip=128.55.173.52) }
# (RayTrainWorker pid=67428, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67428, ip=128.55.173.52)   key: "metadata"
# (RayTrainWorker pid=67428, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67428, ip=128.55.173.52)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=67428, ip=128.55.173.52)   }
# (RayTrainWorker pid=67428, ip=128.55.173.52) }
# (RayTrainWorker pid=67428, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67428, ip=128.55.173.52)   key: "output_shapes"
# (RayTrainWorker pid=67428, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67428, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67428, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67428, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67428, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67428, ip=128.55.173.52)         }
# (RayTrainWorker pid=67428, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67428, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67428, ip=128.55.173.52)         }
# (RayTrainWorker pid=67428, ip=128.55.173.52)       }
# (RayTrainWorker pid=67428, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67428, ip=128.55.173.52)       }
# (RayTrainWorker pid=67428, ip=128.55.173.52)     }
# (RayTrainWorker pid=67428, ip=128.55.173.52)   }
# (RayTrainWorker pid=67428, ip=128.55.173.52) }
# (RayTrainWorker pid=67428, ip=128.55.173.52) experimental_type {
# (RayTrainWorker pid=67428, ip=128.55.173.52)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=67428, ip=128.55.173.52)   args {
# (RayTrainWorker pid=67428, ip=128.55.173.52)     type_id: TFT_DATASET
# (RayTrainWorker pid=67428, ip=128.55.173.52)     args {
# (RayTrainWorker pid=67428, ip=128.55.173.52)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=67428, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67428, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67428, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67428, ip=128.55.173.52)           type_id: TFT_FLOAT
# (RayTrainWorker pid=67428, ip=128.55.173.52)         }
# (RayTrainWorker pid=67428, ip=128.55.173.52)       }
# (RayTrainWorker pid=67428, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67428, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67428, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67428, ip=128.55.173.52)           type_id: TFT_INT64
# (RayTrainWorker pid=67428, ip=128.55.173.52)         }
# (RayTrainWorker pid=67428, ip=128.55.173.52)       }
# (RayTrainWorker pid=67428, ip=128.55.173.52)     }
# (RayTrainWorker pid=67428, ip=128.55.173.52)   }
# (RayTrainWorker pid=67428, ip=128.55.173.52) }
# (RayTrainWorker pid=67428, ip=128.55.173.52)
# (RayTrainWorker pid=67425, ip=128.55.173.52) 2023-05-04 13:22:50.592849: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=67425, ip=128.55.173.52) op: "TensorSliceDataset"
# (RayTrainWorker pid=67425, ip=128.55.173.52) input: "Placeholder/_0"
# (RayTrainWorker pid=67425, ip=128.55.173.52) input: "Placeholder/_1"
# (RayTrainWorker pid=67425, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67425, ip=128.55.173.52)   key: "Toutput_types"
# (RayTrainWorker pid=67425, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67425, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67425, ip=128.55.173.52)       type: DT_FLOAT
# (RayTrainWorker pid=67425, ip=128.55.173.52)       type: DT_INT64
# (RayTrainWorker pid=67425, ip=128.55.173.52)     }
# (RayTrainWorker pid=67425, ip=128.55.173.52)   }
# (RayTrainWorker pid=67425, ip=128.55.173.52) }
# (RayTrainWorker pid=67425, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67425, ip=128.55.173.52)   key: "_cardinality"
# (RayTrainWorker pid=67425, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67425, ip=128.55.173.52)     i: 60000
# (RayTrainWorker pid=67425, ip=128.55.173.52)   }
# (RayTrainWorker pid=67425, ip=128.55.173.52) }
# (RayTrainWorker pid=67425, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67425, ip=128.55.173.52)   key: "is_files"
# (RayTrainWorker pid=67425, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67425, ip=128.55.173.52)     b: false
# (RayTrainWorker pid=67425, ip=128.55.173.52)   }
# (RayTrainWorker pid=67425, ip=128.55.173.52) }
# (RayTrainWorker pid=67425, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67425, ip=128.55.173.52)   key: "metadata"
# (RayTrainWorker pid=67425, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67425, ip=128.55.173.52)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=67425, ip=128.55.173.52)   }
# (RayTrainWorker pid=67425, ip=128.55.173.52) }
# (RayTrainWorker pid=67425, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67425, ip=128.55.173.52)   key: "output_shapes"
# (RayTrainWorker pid=67425, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67425, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67425, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67425, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67425, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67425, ip=128.55.173.52)         }
# (RayTrainWorker pid=67425, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67425, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67425, ip=128.55.173.52)         }
# (RayTrainWorker pid=67425, ip=128.55.173.52)       }
# (RayTrainWorker pid=67425, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67425, ip=128.55.173.52)       }
# (RayTrainWorker pid=67425, ip=128.55.173.52)     }
# (RayTrainWorker pid=67425, ip=128.55.173.52)   }
# (RayTrainWorker pid=67425, ip=128.55.173.52) }
# (RayTrainWorker pid=67425, ip=128.55.173.52) experimental_type {
# (RayTrainWorker pid=67425, ip=128.55.173.52)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=67425, ip=128.55.173.52)   args {
# (RayTrainWorker pid=67425, ip=128.55.173.52)     type_id: TFT_DATASET
# (RayTrainWorker pid=67425, ip=128.55.173.52)     args {
# (RayTrainWorker pid=67425, ip=128.55.173.52)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=67425, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67425, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67425, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67425, ip=128.55.173.52)           type_id: TFT_FLOAT
# (RayTrainWorker pid=67425, ip=128.55.173.52)         }
# (RayTrainWorker pid=67425, ip=128.55.173.52)       }
# (RayTrainWorker pid=67425, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67425, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67425, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67425, ip=128.55.173.52)           type_id: TFT_INT64
# (RayTrainWorker pid=67425, ip=128.55.173.52)         }
# (RayTrainWorker pid=67425, ip=128.55.173.52)       }
# (RayTrainWorker pid=67425, ip=128.55.173.52)     }
# (RayTrainWorker pid=67425, ip=128.55.173.52)   }
# (RayTrainWorker pid=67425, ip=128.55.173.52) }
# (RayTrainWorker pid=67425, ip=128.55.173.52)
# (RayTrainWorker pid=67427, ip=128.55.173.52) 2023-05-04 13:22:50.592842: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=67427, ip=128.55.173.52) op: "TensorSliceDataset"
# (RayTrainWorker pid=67427, ip=128.55.173.52) input: "Placeholder/_0"
# (RayTrainWorker pid=67427, ip=128.55.173.52) input: "Placeholder/_1"
# (RayTrainWorker pid=67427, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67427, ip=128.55.173.52)   key: "Toutput_types"
# (RayTrainWorker pid=67427, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67427, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67427, ip=128.55.173.52)       type: DT_FLOAT
# (RayTrainWorker pid=67427, ip=128.55.173.52)       type: DT_INT64
# (RayTrainWorker pid=67427, ip=128.55.173.52)     }
# (RayTrainWorker pid=67427, ip=128.55.173.52)   }
# (RayTrainWorker pid=67427, ip=128.55.173.52) }
# (RayTrainWorker pid=67427, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67427, ip=128.55.173.52)   key: "_cardinality"
# (RayTrainWorker pid=67427, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67427, ip=128.55.173.52)     i: 60000
# (RayTrainWorker pid=67427, ip=128.55.173.52)   }
# (RayTrainWorker pid=67427, ip=128.55.173.52) }
# (RayTrainWorker pid=67427, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67427, ip=128.55.173.52)   key: "is_files"
# (RayTrainWorker pid=67427, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67427, ip=128.55.173.52)     b: false
# (RayTrainWorker pid=67427, ip=128.55.173.52)   }
# (RayTrainWorker pid=67427, ip=128.55.173.52) }
# (RayTrainWorker pid=67427, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67427, ip=128.55.173.52)   key: "metadata"
# (RayTrainWorker pid=67427, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67427, ip=128.55.173.52)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=67427, ip=128.55.173.52)   }
# (RayTrainWorker pid=67427, ip=128.55.173.52) }
# (RayTrainWorker pid=67427, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67427, ip=128.55.173.52)   key: "output_shapes"
# (RayTrainWorker pid=67427, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67427, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67427, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67427, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67427, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67427, ip=128.55.173.52)         }
# (RayTrainWorker pid=67427, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67427, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67427, ip=128.55.173.52)         }
# (RayTrainWorker pid=67427, ip=128.55.173.52)       }
# (RayTrainWorker pid=67427, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67427, ip=128.55.173.52)       }
# (RayTrainWorker pid=67427, ip=128.55.173.52)     }
# (RayTrainWorker pid=67427, ip=128.55.173.52)   }
# (RayTrainWorker pid=67427, ip=128.55.173.52) }
# (RayTrainWorker pid=67427, ip=128.55.173.52) experimental_type {
# (RayTrainWorker pid=67427, ip=128.55.173.52)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=67427, ip=128.55.173.52)   args {
# (RayTrainWorker pid=67427, ip=128.55.173.52)     type_id: TFT_DATASET
# (RayTrainWorker pid=67427, ip=128.55.173.52)     args {
# (RayTrainWorker pid=67427, ip=128.55.173.52)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=67427, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67427, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67427, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67427, ip=128.55.173.52)           type_id: TFT_FLOAT
# (RayTrainWorker pid=67427, ip=128.55.173.52)         }
# (RayTrainWorker pid=67427, ip=128.55.173.52)       }
# (RayTrainWorker pid=67427, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67427, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67427, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67427, ip=128.55.173.52)           type_id: TFT_INT64
# (RayTrainWorker pid=67427, ip=128.55.173.52)         }
# (RayTrainWorker pid=67427, ip=128.55.173.52)       }
# (RayTrainWorker pid=67427, ip=128.55.173.52)     }
# (RayTrainWorker pid=67427, ip=128.55.173.52)   }
# (RayTrainWorker pid=67427, ip=128.55.173.52) }
# (RayTrainWorker pid=67427, ip=128.55.173.52)
# (RayTrainWorker pid=67426, ip=128.55.173.52) 2023-05-04 13:22:50.592852: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=67426, ip=128.55.173.52) op: "TensorSliceDataset"
# (RayTrainWorker pid=67426, ip=128.55.173.52) input: "Placeholder/_0"
# (RayTrainWorker pid=67426, ip=128.55.173.52) input: "Placeholder/_1"
# (RayTrainWorker pid=67426, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67426, ip=128.55.173.52)   key: "Toutput_types"
# (RayTrainWorker pid=67426, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67426, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67426, ip=128.55.173.52)       type: DT_FLOAT
# (RayTrainWorker pid=67426, ip=128.55.173.52)       type: DT_INT64
# (RayTrainWorker pid=67426, ip=128.55.173.52)     }
# (RayTrainWorker pid=67426, ip=128.55.173.52)   }
# (RayTrainWorker pid=67426, ip=128.55.173.52) }
# (RayTrainWorker pid=67426, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67426, ip=128.55.173.52)   key: "_cardinality"
# (RayTrainWorker pid=67426, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67426, ip=128.55.173.52)     i: 60000
# (RayTrainWorker pid=67426, ip=128.55.173.52)   }
# (RayTrainWorker pid=67426, ip=128.55.173.52) }
# (RayTrainWorker pid=67426, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67426, ip=128.55.173.52)   key: "is_files"
# (RayTrainWorker pid=67426, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67426, ip=128.55.173.52)     b: false
# (RayTrainWorker pid=67426, ip=128.55.173.52)   }
# (RayTrainWorker pid=67426, ip=128.55.173.52) }
# (RayTrainWorker pid=67426, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67426, ip=128.55.173.52)   key: "metadata"
# (RayTrainWorker pid=67426, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67426, ip=128.55.173.52)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=67426, ip=128.55.173.52)   }
# (RayTrainWorker pid=67426, ip=128.55.173.52) }
# (RayTrainWorker pid=67426, ip=128.55.173.52) attr {
# (RayTrainWorker pid=67426, ip=128.55.173.52)   key: "output_shapes"
# (RayTrainWorker pid=67426, ip=128.55.173.52)   value {
# (RayTrainWorker pid=67426, ip=128.55.173.52)     list {
# (RayTrainWorker pid=67426, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67426, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67426, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67426, ip=128.55.173.52)         }
# (RayTrainWorker pid=67426, ip=128.55.173.52)         dim {
# (RayTrainWorker pid=67426, ip=128.55.173.52)           size: 28
# (RayTrainWorker pid=67426, ip=128.55.173.52)         }
# (RayTrainWorker pid=67426, ip=128.55.173.52)       }
# (RayTrainWorker pid=67426, ip=128.55.173.52)       shape {
# (RayTrainWorker pid=67426, ip=128.55.173.52)       }
# (RayTrainWorker pid=67426, ip=128.55.173.52)     }
# (RayTrainWorker pid=67426, ip=128.55.173.52)   }
# (RayTrainWorker pid=67426, ip=128.55.173.52) }
# (RayTrainWorker pid=67426, ip=128.55.173.52) experimental_type {
# (RayTrainWorker pid=67426, ip=128.55.173.52)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=67426, ip=128.55.173.52)   args {
# (RayTrainWorker pid=67426, ip=128.55.173.52)     type_id: TFT_DATASET
# (RayTrainWorker pid=67426, ip=128.55.173.52)     args {
# (RayTrainWorker pid=67426, ip=128.55.173.52)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=67426, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67426, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67426, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67426, ip=128.55.173.52)           type_id: TFT_FLOAT
# (RayTrainWorker pid=67426, ip=128.55.173.52)         }
# (RayTrainWorker pid=67426, ip=128.55.173.52)       }
# (RayTrainWorker pid=67426, ip=128.55.173.52)       args {
# (RayTrainWorker pid=67426, ip=128.55.173.52)         type_id: TFT_TENSOR
# (RayTrainWorker pid=67426, ip=128.55.173.52)         args {
# (RayTrainWorker pid=67426, ip=128.55.173.52)           type_id: TFT_INT64
# (RayTrainWorker pid=67426, ip=128.55.173.52)         }
# (RayTrainWorker pid=67426, ip=128.55.173.52)       }
# (RayTrainWorker pid=67426, ip=128.55.173.52)     }
# (RayTrainWorker pid=67426, ip=128.55.173.52)   }
# (RayTrainWorker pid=67426, ip=128.55.173.52) }
# (RayTrainWorker pid=67426, ip=128.55.173.52)
# (RayTrainWorker pid=65114) 2023-05-04 13:22:50.589040: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=65114) op: "TensorSliceDataset"
# (RayTrainWorker pid=65114) input: "Placeholder/_0"
# (RayTrainWorker pid=65114) input: "Placeholder/_1"
# (RayTrainWorker pid=65114) attr {
# (RayTrainWorker pid=65114)   key: "Toutput_types"
# (RayTrainWorker pid=65114)   value {
# (RayTrainWorker pid=65114)     list {
# (RayTrainWorker pid=65114)       type: DT_FLOAT
# (RayTrainWorker pid=65114)       type: DT_INT64
# (RayTrainWorker pid=65114)     }
# (RayTrainWorker pid=65114)   }
# (RayTrainWorker pid=65114) }
# (RayTrainWorker pid=65114) attr {
# (RayTrainWorker pid=65114)   key: "_cardinality"
# (RayTrainWorker pid=65114)   value {
# (RayTrainWorker pid=65114)     i: 60000
# (RayTrainWorker pid=65114)   }
# (RayTrainWorker pid=65114) }
# (RayTrainWorker pid=65114) attr {
# (RayTrainWorker pid=65114)   key: "is_files"
# (RayTrainWorker pid=65114)   value {
# (RayTrainWorker pid=65114)     b: false
# (RayTrainWorker pid=65114)   }
# (RayTrainWorker pid=65114) }
# (RayTrainWorker pid=65114) attr {
# (RayTrainWorker pid=65114)   key: "metadata"
# (RayTrainWorker pid=65114)   value {
# (RayTrainWorker pid=65114)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=65114)   }
# (RayTrainWorker pid=65114) }
# (RayTrainWorker pid=65114) attr {
# (RayTrainWorker pid=65114)   key: "output_shapes"
# (RayTrainWorker pid=65114)   value {
# (RayTrainWorker pid=65114)     list {
# ...
# (RayTrainWorker pid=73367, ip=128.55.173.52) ray::RayTrainWorker(PyObject_ClearWeakRefs+0xf1) [0x509ae1] PyObject_ClearWeakRefs
# (RayTrainWorker pid=73367, ip=128.55.173.52) ray::RayTrainWorker() [0x496ce5] localdummy_dealloc.cold
# (RayTrainWorker pid=73367, ip=128.55.173.52) ray::RayTrainWorker() [0x4e4037] dict_dealloc
# (RayTrainWorker pid=73367, ip=128.55.173.52) ray::RayTrainWorker(PyThreadState_Clear+0x138) [0x5c5bc8] PyThreadState_Clear
# (RayTrainWorker pid=73367, ip=128.55.173.52) ray::RayTrainWorker() [0x5dc95b] t_bootstrap
# (RayTrainWorker pid=73367, ip=128.55.173.52) ray::RayTrainWorker() [0x5dc8a4] pythread_wrapper
# (RayTrainWorker pid=73367, ip=128.55.173.52) /lib64/libpthread.so.0(+0xa6ea) [0x7f84e91196ea] start_thread
# (RayTrainWorker pid=73367, ip=128.55.173.52) /lib64/libc.so.6(clone+0x3f) [0x7f84e86dea6f] clone
# (RayTrainWorker pid=73367, ip=128.55.173.52)
# (RayTrainWorker pid=73366, ip=128.55.173.52) [2023-05-04 13:23:50,207 E 73366 76770] logging.cc:104: Stack trace:
# (RayTrainWorker pid=73366, ip=128.55.173.52)  /global/homes/a/asnaylor/.local/muller/tensorflow2.9.0/lib/python3.9/site-packages/ray/_raylet.so(+0xd5621a) [0x7fa7da0b121a] ray::operator<<()
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/homes/a/asnaylor/.local/muller/tensorflow2.9.0/lib/python3.9/site-packages/ray/_raylet.so(+0xd589d8) [0x7fa7da0b39d8] ray::TerminateHandler()
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libstdc++.so.6(+0xb135a) [0x7fa7d8fcd35a] __cxxabiv1::__terminate()
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libstdc++.so.6(+0xb13c5) [0x7fa7d8fcd3c5]
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libstdc++.so.6(__gxx_personality_v0+0x2bc) [0x7fa7d8fccd1c] __gxx_personality_v0
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libgcc_s.so.1(+0x11354) [0x7fa7d8f13354] _Unwind_ForcedUnwind_Phase2
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libgcc_s.so.1(_Unwind_ForcedUnwind+0x132) [0x7fa7d8f13a42] _Unwind_ForcedUnwind
# (RayTrainWorker pid=73366, ip=128.55.173.52) /lib64/libpthread.so.0(__pthread_unwind+0x42) [0x7fa7db49a1f0] __pthread_unwind
# (RayTrainWorker pid=73366, ip=128.55.173.52) /lib64/libpthread.so.0(+0xb9cc) [0x7fa7db4909cc]
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x49dbf2] _append_preinit_entry.isra.0
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x42396c] take_gil.cold
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker(PyEval_RestoreThread+0x12) [0x514242] PyEval_RestoreThread
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/site-packages/tensorflow/python/client/_pywrap_tf_session.so(+0x803a5) [0x7f94644ed3a5] pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()
# (RayTrainWorker pid=73366, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/site-packages/tensorflow/python/client/_pywrap_tf_session.so(+0x87eb1) [0x7f94644f4eb1] pybind11::cpp_function::dispatcher()
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x507457] cfunction_call
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker(_PyObject_MakeTpCall+0x2ec) [0x4f068c] _PyObject_MakeTpCall
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker(_PyEval_EvalFrameDefault+0x525b) [0x4ec9fb] _PyEval_EvalFrameDefault
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x4f7f33] function_code_fastcall
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x5300fe] PyObject_CallOneArg.lto_priv.7
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x5c8a6e] slot_tp_finalize
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker(PyObject_CallFinalizerFromDealloc+0x3b) [0x50c71b] PyObject_CallFinalizerFromDealloc
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x509518] subtype_dealloc
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x4e40b6] dict_dealloc
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x509344] subtype_dealloc
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x4e4037] dict_dealloc
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker(_PyDict_DelItem_KnownHash+0x274) [0x4e3344] _PyDict_DelItem_KnownHash
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x4bf3b7] _localdummy_destroyed
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x4f73cb] cfunction_vectorcall_O
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x60fc01] _PyObject_VectorcallTstate.lto_priv.40
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x594f2f] PyObject_CallOneArg.lto_priv.3
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x598a2f] handle_callback
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker(PyObject_ClearWeakRefs+0xf1) [0x509ae1] PyObject_ClearWeakRefs
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x496ce5] localdummy_dealloc.cold
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x4e4037] dict_dealloc
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker(PyThreadState_Clear+0x138) [0x5c5bc8] PyThreadState_Clear
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x5dc95b] t_bootstrap
# (RayTrainWorker pid=73366, ip=128.55.173.52) ray::RayTrainWorker() [0x5dc8a4] pythread_wrapper
# (RayTrainWorker pid=73366, ip=128.55.173.52) /lib64/libpthread.so.0(+0xa6ea) [0x7fa7db48f6ea] start_thread
# (RayTrainWorker pid=73366, ip=128.55.173.52) /lib64/libc.so.6(clone+0x3f) [0x7fa7daa54a6f] clone
# (RayTrainWorker pid=73366, ip=128.55.173.52)
# (RayTrainWorker pid=73365, ip=128.55.173.52) [2023-05-04 13:23:50,205 E 73365 76754] logging.cc:104: Stack trace:
# (RayTrainWorker pid=73365, ip=128.55.173.52)  /global/homes/a/asnaylor/.local/muller/tensorflow2.9.0/lib/python3.9/site-packages/ray/_raylet.so(+0xd5621a) [0x7f2ea72a821a] ray::operator<<()
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/homes/a/asnaylor/.local/muller/tensorflow2.9.0/lib/python3.9/site-packages/ray/_raylet.so(+0xd589d8) [0x7f2ea72aa9d8] ray::TerminateHandler()
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libstdc++.so.6(+0xb135a) [0x7f2ea61c435a] __cxxabiv1::__terminate()
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libstdc++.so.6(+0xb13c5) [0x7f2ea61c43c5]
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libstdc++.so.6(__gxx_personality_v0+0x2bc) [0x7f2ea61c3d1c] __gxx_personality_v0
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libgcc_s.so.1(+0x11354) [0x7f2ea610a354] _Unwind_ForcedUnwind_Phase2
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/bin/../lib/libgcc_s.so.1(_Unwind_ForcedUnwind+0x132) [0x7f2ea610aa42] _Unwind_ForcedUnwind
# (RayTrainWorker pid=73365, ip=128.55.173.52) /lib64/libpthread.so.0(__pthread_unwind+0x42) [0x7f2ea86911f0] __pthread_unwind
# (RayTrainWorker pid=73365, ip=128.55.173.52) /lib64/libpthread.so.0(+0xb9cc) [0x7f2ea86879cc]
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x49dbf2] _append_preinit_entry.isra.0
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x42396c] take_gil.cold
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker(PyEval_RestoreThread+0x12) [0x514242] PyEval_RestoreThread
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/site-packages/tensorflow/python/client/_pywrap_tf_session.so(+0x803a5) [0x7f1b284ed3a5] pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()
# (RayTrainWorker pid=73365, ip=128.55.173.52) /global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/site-packages/tensorflow/python/client/_pywrap_tf_session.so(+0x87eb1) [0x7f1b284f4eb1] pybind11::cpp_function::dispatcher()
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x507457] cfunction_call
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker(_PyObject_MakeTpCall+0x2ec) [0x4f068c] _PyObject_MakeTpCall
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker(_PyEval_EvalFrameDefault+0x525b) [0x4ec9fb] _PyEval_EvalFrameDefault
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x4f7f33] function_code_fastcall
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x5300fe] PyObject_CallOneArg.lto_priv.7
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x5c8a6e] slot_tp_finalize
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker(PyObject_CallFinalizerFromDealloc+0x3b) [0x50c71b] PyObject_CallFinalizerFromDealloc
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x509518] subtype_dealloc
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x4e40b6] dict_dealloc
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x509344] subtype_dealloc
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x4e4037] dict_dealloc
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker(_PyDict_DelItem_KnownHash+0x274) [0x4e3344] _PyDict_DelItem_KnownHash
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x4bf3b7] _localdummy_destroyed
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x4f73cb] cfunction_vectorcall_O
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x60fc01] _PyObject_VectorcallTstate.lto_priv.40
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x594f2f] PyObject_CallOneArg.lto_priv.3
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x598a2f] handle_callback
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker(PyObject_ClearWeakRefs+0xf1) [0x509ae1] PyObject_ClearWeakRefs
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x496ce5] localdummy_dealloc.cold
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x4e4037] dict_dealloc
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker(PyThreadState_Clear+0x138) [0x5c5bc8] PyThreadState_Clear
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x5dc95b] t_bootstrap
# (RayTrainWorker pid=73365, ip=128.55.173.52) ray::RayTrainWorker() [0x5dc8a4] pythread_wrapper
# (RayTrainWorker pid=73365, ip=128.55.173.52) /lib64/libpthread.so.0(+0xa6ea) [0x7f2ea86866ea] start_thread
# (RayTrainWorker pid=73365, ip=128.55.173.52) /lib64/libc.so.6(clone+0x3f) [0x7f2ea7c4ba6f] clone
# (RayTrainWorker pid=73365, ip=128.55.173.52)
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:06.479970034-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.344382ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:08.046006495-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.994005ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.500446134-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.399928ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.719966573-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.295206ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.758904775-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.951844ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.801727035-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.518868ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.840382071-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.264177ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.880511432-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.232034ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.922278585-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.238527ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:09.961442363-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=23 duration=23.277763ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.000188935-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.748932ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.032330698-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.266931ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.071982107-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.173242ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.105856554-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.340564ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.136275442-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.464913ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.169374894-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.889975ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.200519021-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=22 duration=22.393967ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:10.625297079-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=21 duration=21.667715ms size=0 referer= handler=/api/live/ws
# logger=context userId=0 orgId=1 uname= t=2023-05-04T13:24:12.332745017-07:00 level=info msg="Request Completed" method=GET path=/api/live/ws status=-1 remote_addr=192.184.142.228 time_ms=23 duration=23.353269ms size=0 referer= handler=/api/live/ws

# %%
log_dir = str(results.get_best_result().log_dir)

# %%
log_dir
# Out:
# '/global/homes/a/asnaylor/ray_results/TensorflowTrainer_2023-05-04_13-22-29/TensorflowTrainer_64592_00001_1_batch_size=128,lr=0.0987_2023-05-04_13-23-16'

# %% [markdown]
# ## Close cluster conection and stop job

# %%
ray.shutdown()

# %%
rayCluster.shutdown()
# Out:
# {'task_id': '0', 'status': 'OK', 'error': None}

# %%
# !scancel -u "$USER"

# %% [markdown]
# ## Explore Training in Tensorboard

# %%
import nersc_tensorboard_helper
# %load_ext tensorboard

# %%
# %tensorboard --logdir $log_dir --port 0
# Out:
#       <iframe id="tensorboard-frame-e2a83a6e34135502" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e2a83a6e34135502");
#           const url = new URL("/", window.location);
#           const port = 43765;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
nersc_tensorboard_helper.tb_address()
# Out:
# <a href="https://jupyter.nersc.gov/user/asnaylor/muller-configurable-gpu/proxy/43765/">https://jupyter.nersc.gov/user/asnaylor/muller-configurable-gpu/proxy/43765/</a>
# logger=cleanup t=2023-05-04T13:30:34.993048016-07:00 level=info msg="Completed cleanup jobs" duration=21.267014ms
# logger=cleanup t=2023-05-04T13:40:34.989994269-07:00 level=info msg="Completed cleanup jobs" duration=18.38086ms
