# %% [markdown]
# # NERSC Cluster Deploy Tutorial: Tuning Hyperparameters of a Distributed TensorFlow Model using Ray Train & Tune
#
# 📖 [Back to Table of Contents](../README.md)<br>
# ⬅ [Previous notebook](./ex_01_pytorch_ray_train_tune.ipynb) <br>
# <!-- ➡ [Next notebook](./ex_03_pytorch_ray_hvd.ipynb) <br> -->
#
# ----
#
#
# ## Introduction
#
# We are going to run an example Ray Train & Tune code. This example looks at tunning hyperparameters of a distrbuted TensorFlow Model. This tutorial is following the code in this example:
# https://docs.ray.io/en/latest/train/examples/tf/tune_tensorflow_mnist_example.html
#
# > **Note**:
# > To setup the environment for the notebook, execute on command line: `./setup.sh 2` then select the kernel `tensorflow-2.9.0` in the notebook
#
# This Ray cluster will be setup using the NERSC TensorFlow module and deployed on Perlmutter.

# %% [markdown]
# # Starting Ray Cluster
#
# ## Superfacility API
#
# To deploy the Ray cluster via the NERSC Superfacility API you require a valid API client.
#
# To create a valid client visit your profile page in [Iris](https://iris.nersc.gov/):
#
# <img src="img/iris_profile_header.png" width="800" />
#
# Then scroll down to the **Superfacility API Clients** section and click the "+ New Client" button which will produce this window:
#
# <img src="img/new_sf_api_client.png" width="400" />
#
# ![title](img/new_sf_api_client.png)
#
# To submit and deploy a Ray cluster we require the highest security level (<span style="color:red">RED</span>). **[This client id is valid for 2 days]**
#
# Once created then saved the `client_id` string and `private_key` dictionary (you can also save the private key in PEM format) ready for use with the `SuperfacilityAPI` library.
#
# > **Note**:
# > This step should only be repeated if your client has expired
#
#
# For more information about the NERSC Superfacility API visit the [documenation](https://docs.nersc.gov/services/sfapi/).

# %%
from SuperfacilityAPI import SuperfacilityAPI, SuperfacilityAccessToken
from utility import load_secrets

# Replace with your client id string and private key dictionary
client_id, private_key = load_secrets()
# client_id = "<your client id string>"
# private_key = "<your private key dict>"

api_key = SuperfacilityAccessToken(
    client_id = client_id,
    private_key = private_key
)
sfp_api = SuperfacilityAPI(api_key)

# %% [markdown]
# ## Creating Ray Cluster
#
# To create a ray cluster on NERSC compute nodes, execute the `deploy_ray_cluster` function with your desired slurm sbatch options.

# %%
from nersc_cluster_deploy import deploy_ray_cluster
from utility import user_account

slurm_options = {
    'qos': 'debug',
    'account': user_account(),
    'nodes': '2',
    't': '00:30:00'
}
site = 'perlmutter'
module_load = 'tensorflow/2.9.0'

job = deploy_ray_cluster(
    sfp_api,
    slurm_options,
    site,
    job_setup = [f'module load {module_load}']
)

# %%
job
# Out:
# {'error': None, 'jobid': '5906487', 'task_id': '11934'}

# %% [markdown]
# Now the job has been submitted, check on the job status

# %%
import os
import pandas as pd
sqs_table = sfp_api.get_jobs(site=site, user=os.getlogin(), sacct=False)
sqs_df = pd.DataFrame(sqs_table['output'])
sqs_df
# Out:
#      account tres_per_node min_cpus min_tmp_disk             end_time  \
# 0  dasrepo_g           N/A      128            0  2023-03-03T20:04:04
#
#           features  group over_subscribe    jobid    name  ... partition  \
# 0  gpu&a100&hbm40g  75235             NO  5906487  sbatch  ...  gpu_ss11
#
#      nodelist(reason)           start_time    state    uid  \
# 0  nid[001084,002408]  2023-03-03T19:34:04  RUNNING  75235
#
#            submit_time licenses core_spec schednodes               work_dir
# 0  2023-03-03T19:34:03     u2:1       N/A     (null)  /global/u2/a/asnaylor
#
# [1 rows x 49 columns]

# %% [markdown]
# Check job log

# %%
# !cat ~/slurm-{job['jobid']}.out
# Out:
# Warning: This is an experimental release of NCCL with an OFI plugin for use with libfabric on Perlmutter.
# In case of issues, please refer to our known issues: https://docs.nersc.gov/current/
# and open a help ticket if your issue is not listed: https://help.nersc.gov/
# [slurm] - Starting ray HEAD
# 2023-03-03 19:34:09,561	INFO usage_lib.py:435 -- Usage stats collection is disabled.
# 2023-03-03 19:34:09,561	INFO scripts.py:710 -- Local node IP: nid001084
# 2023-03-03 19:34:12,083	SUCC scripts.py:747 -- --------------------
# 2023-03-03 19:34:12,083	SUCC scripts.py:748 -- Ray runtime started.
# 2023-03-03 19:34:12,083	SUCC scripts.py:749 -- --------------------
# 2023-03-03 19:34:12,083	INFO scripts.py:751 -- Next steps
# 2023-03-03 19:34:12,083	INFO scripts.py:752 -- To connect to this Ray runtime from another node, run
# 2023-03-03 19:34:12,083	INFO scripts.py:755 --   ray start --address='nid001084:6379'
# 2023-03-03 19:34:12,083	INFO scripts.py:771 -- Alternatively, use the following Python code:
# 2023-03-03 19:34:12,084	INFO scripts.py:773 -- import ray
# 2023-03-03 19:34:12,084	INFO scripts.py:777 -- ray.init(address='auto', _node_ip_address='nid001084')
# 2023-03-03 19:34:12,084	INFO scripts.py:790 -- To see the status of the cluster, use
# 2023-03-03 19:34:12,084	INFO scripts.py:791 --   ray status
# 2023-03-03 19:34:12,084	INFO scripts.py:794 -- To monitor and debug Ray, view the dashboard at
# 2023-03-03 19:34:12,084	INFO scripts.py:795 --   127.0.0.1:8265
# 2023-03-03 19:34:12,084	INFO scripts.py:801 -- If connection fails, check your firewall settings and network configuration.
# 2023-03-03 19:34:12,084	INFO scripts.py:809 -- To terminate the Ray runtime, run
# 2023-03-03 19:34:12,084	INFO scripts.py:810 --   ray stop
# 2023-03-03 19:34:12,084	INFO scripts.py:888 -- --block
# 2023-03-03 19:34:12,084	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-03-03 19:34:12,084	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.
# [slurm] - Starting 1 ray worker nodes
#     - 1 at nid002408
# [2023-03-03 19:34:38,834 I 3873 3873] global_state_accessor.cc:356: This node has an IP address of 128.55.66.148, while we can not find the matched Raylet address. This maybe come from when you connect the Ray cluster with a different IP address or connect a container.
# 2023-03-03 19:34:38,686	INFO scripts.py:866 -- Local node IP: 128.55.66.148
# 2023-03-03 19:34:38,835	SUCC scripts.py:878 -- --------------------
# 2023-03-03 19:34:38,835	SUCC scripts.py:879 -- Ray runtime started.
# 2023-03-03 19:34:38,835	SUCC scripts.py:880 -- --------------------
# 2023-03-03 19:34:38,835	INFO scripts.py:882 -- To terminate the Ray runtime, run
# 2023-03-03 19:34:38,835	INFO scripts.py:883 --   ray stop
# 2023-03-03 19:34:38,835	INFO scripts.py:888 -- --block
# 2023-03-03 19:34:38,835	INFO scripts.py:889 -- This command will now block forever until terminated by a signal.
# 2023-03-03 19:34:38,835	INFO scripts.py:892 -- Running subprocesses are monitored and a message will be printed if any of them terminate unexpectedly. Subprocesses exit with SIGTERM will be treated as graceful, thus NOT reported.

# %% [markdown]
# ## Connect to Ray Cluster
#
# Get the Ray cluster head node ip address to connect to the cluster

# %%
from nersc_cluster_deploy import get_ray_cluster_address
import ray

cluster_address = get_ray_cluster_address(
    sfp_api,
    job['jobid'],
    site
)
ray.init(cluster_address)
# Out:
# ClientContext(dashboard_url='127.0.0.1:8265', python_version='3.9.15', ray_version='2.3.0', ray_commit='cf7a56b4b0b648c324722df7c99c168e92ff0b45', protocol_version='2022-12-06', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x14ede9659850>)

# %% [markdown]
# Check all nodes connected to cluster

# %%
from nersc_cluster_deploy import ray_cluster_summary

ray_cluster_summary()
# Out:
# Cluster Summary
# ---------------
# Nodes: 2
# CPU:   256
# GPU:   8
# RAM:   307.8 GB

# %% [markdown]
# ## Setup PyTorch Model

# %%
from ray import tune
from ray.train.tensorflow import TensorflowTrainer
from ray.air.config import ScalingConfig

from ray.train.examples.tf.tensorflow_mnist_example import train_func
from ray.tune.tune_config import TuneConfig
from ray.tune.tuner import Tuner

# %%
def tune_tensorflow_mnist(
    num_workers: int = 2, num_samples: int = 2, use_gpu: bool = False
):
    trainer = TensorflowTrainer(
        train_loop_per_worker=train_func,
        scaling_config=ScalingConfig(num_workers=num_workers, use_gpu=use_gpu),
    )
    tuner = Tuner(
        trainer,
        tune_config=TuneConfig(num_samples=num_samples, metric="accuracy", mode="max"),
        param_space={
            "train_loop_config": {
                "lr": tune.loguniform(1e-4, 1e-1),
                "batch_size": tune.choice([32, 64, 128]),
                "epochs": 3,
            }
        },
    )
    results = tuner.fit()
    best_accuracy = results.get_best_result().metrics["accuracy"]
    print(f"Best accuracy config: {best_accuracy}")
    return results

# %% [markdown]
# ## Train Model

# %%
node_resources = ray.cluster_resources()
num_workers = int(node_resources['GPU'])
use_gpu = True

num_samples = 2
smoke_test = False

# %%
results = tune_tensorflow_mnist(
            num_workers=num_workers,
            num_samples=num_samples,
            use_gpu=use_gpu,
)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-03-03 19:36:04</td></tr>
# <tr><td>Running for: </td><td>00:00:56.40        </td></tr>
# <tr><td>Memory:      </td><td>58.5/251.3 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 0/256 CPUs, 0/8 GPUs, 0.0/307.8 GiB heap, 0.0/135.9 GiB objects (0.0/2.0 accelerator_type:A100)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc               </th><th style="text-align: right;">   train_loop_config/ba
# tch_size</th><th style="text-align: right;">  train_loop_config/lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  _timestamp</th></tr>
# </thead>
# <tbody>
# <tr><td>TensorflowTrainer_8f7c2_00000</td><td>TERMINATED</td><td>pid=77617         </td><td style="text-align: right;">64</td><td style="text-align: right;">           0.00248349 </td><td style="text-align: right;">     3</td><td style="text-align: right;">         24.3731</td><td style="text-align: right;">1.7592 </td><td style="text-align: right;">  0.641936</td><td style="text-align: right;">  1677900935</td></tr>
# <tr><td>TensorflowTrainer_8f7c2_00001</td><td>TERMINATED</td><td>128.55.66.148:8644</td><td style="text-align: right;">32</td><td style="text-align: right;">           0.000111707</td><td style="text-align: right;">     3</td><td style="text-align: right;">         18.1692</td><td style="text-align: right;">2.29254</td><td style="text-align: right;">  0.116016</td><td style="text-align: right;">  1677900960</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (TunerInternal pid=77000) 2023-03-03 19:35:08,196	WARNING trial_runner.py:369 -- The maximum number of pending trials has been automatically set to the number of available cluster CPUs, which is high (281 CPUs/pending trials). If you're running an experiment with a large number of trials, this could lead to scheduling overhead. In this case, consider setting the `TUNE_MAX_PENDING_TRIALS_PG` environment variable to the desired maximum number of concurr
ip=128.55.66.148)       shape {
# (RayTrainWorker pid=4550, ip=128.55.66.148)       }
# (RayTrainWorker pid=4550, ip=128.55.66.148)     }
# (RayTrainWorker pid=4550, ip=128.55.66.148)   }
# (RayTrainWorker pid=4550, ip=128.55.66.148) }
# (RayTrainWorker pid=4550, ip=128.55.66.148) experimental_type {
# (RayTrainWorker pid=4550, ip=128.55.66.148)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=4550, ip=128.55.66.148)   args {
# (RayTrainWorker pid=4550, ip=128.55.66.148)     type_id: TFT_DATASET
# (RayTrainWorker pid=4550, ip=128.55.66.148)     args {
# (RayTrainWorker pid=4550, ip=128.55.66.148)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=4550, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4550, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4550, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4550, ip=128.55.66.148)           type_id: TFT_FLOAT
# (RayTrainWorker pid=4550, ip=128.55.66.148)         }
# (RayTrainWorker pid=4550, ip=128.55.66.148)       }
# (RayTrainWorker pid=4550, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4550, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4550, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4550, ip=128.55.66.148)           type_id: TFT_INT64
# (RayTrainWorker pid=4550, ip=128.55.66.148)         }
# (RayTrainWorker pid=4550, ip=128.55.66.148)       }
# (RayTrainWorker pid=4550, ip=128.55.66.148)     }
# (RayTrainWorker pid=4550, ip=128.55.66.148)   }
# (RayTrainWorker pid=4550, ip=128.55.66.148) }
# (RayTrainWorker pid=4550, ip=128.55.66.148)
# (RayTrainWorker pid=4549, ip=128.55.66.148) 2023-03-03 19:35:22.935022: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=4549, ip=128.55.66.148) op: "TensorSliceDataset"
# (RayTrainWorker pid=4549, ip=128.55.66.148) input: "Placeholder/_0"
# (RayTrainWorker pid=4549, ip=128.55.66.148) input: "Placeholder/_1"
# (RayTrainWorker pid=4549, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4549, ip=128.55.66.148)   key: "Toutput_types"
# (RayTrainWorker pid=4549, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4549, ip=128.55.66.148)     list {
# (RayTrainWorker pid=4549, ip=128.55.66.148)       type: DT_FLOAT
# (RayTrainWorker pid=4549, ip=128.55.66.148)       type: DT_INT64
# (RayTrainWorker pid=4549, ip=128.55.66.148)     }
# (RayTrainWorker pid=4549, ip=128.55.66.148)   }
# (RayTrainWorker pid=4549, ip=128.55.66.148) }
# (RayTrainWorker pid=4549, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4549, ip=128.55.66.148)   key: "_cardinality"
# (RayTrainWorker pid=4549, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4549, ip=128.55.66.148)     i: 60000
# (RayTrainWorker pid=4549, ip=128.55.66.148)   }
# (RayTrainWorker pid=4549, ip=128.55.66.148) }
# (RayTrainWorker pid=4549, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4549, ip=128.55.66.148)   key: "is_files"
# (RayTrainWorker pid=4549, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4549, ip=128.55.66.148)     b: false
# (RayTrainWorker pid=4549, ip=128.55.66.148)   }
# (RayTrainWorker pid=4549, ip=128.55.66.148) }
# (RayTrainWorker pid=4549, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4549, ip=128.55.66.148)   key: "metadata"
# (RayTrainWorker pid=4549, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4549, ip=128.55.66.148)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=4549, ip=128.55.66.148)   }
# (RayTrainWorker pid=4549, ip=128.55.66.148) }
# (RayTrainWorker pid=4549, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4549, ip=128.55.66.148)   key: "output_shapes"
# (RayTrainWorker pid=4549, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4549, ip=128.55.66.148)     list {
# (RayTrainWorker pid=4549, ip=128.55.66.148)       shape {
# (RayTrainWorker pid=4549, ip=128.55.66.148)         dim {
# (RayTrainWorker pid=4549, ip=128.55.66.148)           size: 28
# (RayTrainWorker pid=4549, ip=128.55.66.148)         }
# (RayTrainWorker pid=4549, ip=128.55.66.148)         dim {
# (RayTrainWorker pid=4549, ip=128.55.66.148)           size: 28
# (RayTrainWorker pid=4549, ip=128.55.66.148)         }
# (RayTrainWorker pid=4549, ip=128.55.66.148)       }
# (RayTrainWorker pid=4549, ip=128.55.66.148)       shape {
# (RayTrainWorker pid=4549, ip=128.55.66.148)       }
# (RayTrainWorker pid=4549, ip=128.55.66.148)     }
# (RayTrainWorker pid=4549, ip=128.55.66.148)   }
# (RayTrainWorker pid=4549, ip=128.55.66.148) }
# (RayTrainWorker pid=4549, ip=128.55.66.148) experimental_type {
# (RayTrainWorker pid=4549, ip=128.55.66.148)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=4549, ip=128.55.66.148)   args {
# (RayTrainWorker pid=4549, ip=128.55.66.148)     type_id: TFT_DATASET
# (RayTrainWorker pid=4549, ip=128.55.66.148)     args {
# (RayTrainWorker pid=4549, ip=128.55.66.148)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=4549, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4549, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4549, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4549, ip=128.55.66.148)           type_id: TFT_FLOAT
# (RayTrainWorker pid=4549, ip=128.55.66.148)         }
# (RayTrainWorker pid=4549, ip=128.55.66.148)       }
# (RayTrainWorker pid=4549, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4549, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4549, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4549, ip=128.55.66.148)           type_id: TFT_INT64
# (RayTrainWorker pid=4549, ip=128.55.66.148)         }
# (RayTrainWorker pid=4549, ip=128.55.66.148)       }
# (RayTrainWorker pid=4549, ip=128.55.66.148)     }
# (RayTrainWorker pid=4549, ip=128.55.66.148)   }
# (RayTrainWorker pid=4549, ip=128.55.66.148) }
# (RayTrainWorker pid=4549, ip=128.55.66.148)
# (RayTrainWorker pid=4548, ip=128.55.66.148) 2023-03-03 19:35:22.935019: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=4548, ip=128.55.66.148) op: "TensorSliceDataset"
# (RayTrainWorker pid=4548, ip=128.55.66.148) input: "Placeholder/_0"
# (RayTrainWorker pid=4548, ip=128.55.66.148) input: "Placeholder/_1"
# (RayTrainWorker pid=4548, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4548, ip=128.55.66.148)   key: "Toutput_types"
# (RayTrainWorker pid=4548, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4548, ip=128.55.66.148)     list {
# (RayTrainWorker pid=4548, ip=128.55.66.148)       type: DT_FLOAT
# (RayTrainWorker pid=4548, ip=128.55.66.148)       type: DT_INT64
# (RayTrainWorker pid=4548, ip=128.55.66.148)     }
# (RayTrainWorker pid=4548, ip=128.55.66.148)   }
# (RayTrainWorker pid=4548, ip=128.55.66.148) }
# (RayTrainWorker pid=4548, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4548, ip=128.55.66.148)   key: "_cardinality"
# (RayTrainWorker pid=4548, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4548, ip=128.55.66.148)     i: 60000
# (RayTrainWorker pid=4548, ip=128.55.66.148)   }
# (RayTrainWorker pid=4548, ip=128.55.66.148) }
# (RayTrainWorker pid=4548, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4548, ip=128.55.66.148)   key: "is_files"
# (RayTrainWorker pid=4548, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4548, ip=128.55.66.148)     b: false
# (RayTrainWorker pid=4548, ip=128.55.66.148)   }
# (RayTrainWorker pid=4548, ip=128.55.66.148) }
# (RayTrainWorker pid=4548, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4548, ip=128.55.66.148)   key: "metadata"
# (RayTrainWorker pid=4548, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4548, ip=128.55.66.148)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=4548, ip=128.55.66.148)   }
# (RayTrainWorker pid=4548, ip=128.55.66.148) }
# (RayTrainWorker pid=4548, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4548, ip=128.55.66.148)   key: "output_shapes"
# (RayTrainWorker pid=4548, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4548, ip=128.55.66.148)     list {
# (RayTrainWorker pid=4548, ip=128.55.66.148)       shape {
# (RayTrainWorker pid=4548, ip=128.55.66.148)         dim {
# (RayTrainWorker pid=4548, ip=128.55.66.148)           size: 28
# (RayTrainWorker pid=4548, ip=128.55.66.148)         }
# (RayTrainWorker pid=4548, ip=128.55.66.148)         dim {
# (RayTrainWorker pid=4548, ip=128.55.66.148)           size: 28
# (RayTrainWorker pid=4548, ip=128.55.66.148)         }
# (RayTrainWorker pid=4548, ip=128.55.66.148)       }
# (RayTrainWorker pid=4548, ip=128.55.66.148)       shape {
# (RayTrainWorker pid=4548, ip=128.55.66.148)       }
# (RayTrainWorker pid=4548, ip=128.55.66.148)     }
# (RayTrainWorker pid=4548, ip=128.55.66.148)   }
# (RayTrainWorker pid=4548, ip=128.55.66.148) }
# (RayTrainWorker pid=4548, ip=128.55.66.148) experimental_type {
# (RayTrainWorker pid=4548, ip=128.55.66.148)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=4548, ip=128.55.66.148)   args {
# (RayTrainWorker pid=4548, ip=128.55.66.148)     type_id: TFT_DATASET
# (RayTrainWorker pid=4548, ip=128.55.66.148)     args {
# (RayTrainWorker pid=4548, ip=128.55.66.148)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=4548, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4548, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4548, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4548, ip=128.55.66.148)           type_id: TFT_FLOAT
# (RayTrainWorker pid=4548, ip=128.55.66.148)         }
# (RayTrainWorker pid=4548, ip=128.55.66.148)       }
# (RayTrainWorker pid=4548, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4548, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4548, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4548, ip=128.55.66.148)           type_id: TFT_INT64
# (RayTrainWorker pid=4548, ip=128.55.66.148)         }
# (RayTrainWorker pid=4548, ip=128.55.66.148)       }
# (RayTrainWorker pid=4548, ip=128.55.66.148)     }
# (RayTrainWorker pid=4548, ip=128.55.66.148)   }
# (RayTrainWorker pid=4548, ip=128.55.66.148) }
# (RayTrainWorker pid=4548, ip=128.55.66.148)
# (RayTrainWorker pid=4551, ip=128.55.66.148) 2023-03-03 19:35:22.935027: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=4551, ip=128.55.66.148) op: "TensorSliceDataset"
# (RayTrainWorker pid=4551, ip=128.55.66.148) input: "Placeholder/_0"
# (RayTrainWorker pid=4551, ip=128.55.66.148) input: "Placeholder/_1"
# (RayTrainWorker pid=4551, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4551, ip=128.55.66.148)   key: "Toutput_types"
# (RayTrainWorker pid=4551, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4551, ip=128.55.66.148)     list {
# (RayTrainWorker pid=4551, ip=128.55.66.148)       type: DT_FLOAT
# (RayTrainWorker pid=4551, ip=128.55.66.148)       type: DT_INT64
# (RayTrainWorker pid=4551, ip=128.55.66.148)     }
# (RayTrainWorker pid=4551, ip=128.55.66.148)   }
# (RayTrainWorker pid=4551, ip=128.55.66.148) }
# (RayTrainWorker pid=4551, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4551, ip=128.55.66.148)   key: "_cardinality"
# (RayTrainWorker pid=4551, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4551, ip=128.55.66.148)     i: 60000
# (RayTrainWorker pid=4551, ip=128.55.66.148)   }
# (RayTrainWorker pid=4551, ip=128.55.66.148) }
# (RayTrainWorker pid=4551, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4551, ip=128.55.66.148)   key: "is_files"
# (RayTrainWorker pid=4551, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4551, ip=128.55.66.148)     b: false
# (RayTrainWorker pid=4551, ip=128.55.66.148)   }
# (RayTrainWorker pid=4551, ip=128.55.66.148) }
# (RayTrainWorker pid=4551, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4551, ip=128.55.66.148)   key: "metadata"
# (RayTrainWorker pid=4551, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4551, ip=128.55.66.148)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=4551, ip=128.55.66.148)   }
# (RayTrainWorker pid=4551, ip=128.55.66.148) }
# (RayTrainWorker pid=4551, ip=128.55.66.148) attr {
# (RayTrainWorker pid=4551, ip=128.55.66.148)   key: "output_shapes"
# (RayTrainWorker pid=4551, ip=128.55.66.148)   value {
# (RayTrainWorker pid=4551, ip=128.55.66.148)     list {
# (RayTrainWorker pid=4551, ip=128.55.66.148)       shape {
# (RayTrainWorker pid=4551, ip=128.55.66.148)         dim {
# (RayTrainWorker pid=4551, ip=128.55.66.148)           size: 28
# (RayTrainWorker pid=4551, ip=128.55.66.148)         }
# (RayTrainWorker pid=4551, ip=128.55.66.148)         dim {
# (RayTrainWorker pid=4551, ip=128.55.66.148)           size: 28
# (RayTrainWorker pid=4551, ip=128.55.66.148)         }
# (RayTrainWorker pid=4551, ip=128.55.66.148)       }
# (RayTrainWorker pid=4551, ip=128.55.66.148)       shape {
# (RayTrainWorker pid=4551, ip=128.55.66.148)       }
# (RayTrainWorker pid=4551, ip=128.55.66.148)     }
# (RayTrainWorker pid=4551, ip=128.55.66.148)   }
# (RayTrainWorker pid=4551, ip=128.55.66.148) }
# (RayTrainWorker pid=4551, ip=128.55.66.148) experimental_type {
# (RayTrainWorker pid=4551, ip=128.55.66.148)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=4551, ip=128.55.66.148)   args {
# (RayTrainWorker pid=4551, ip=128.55.66.148)     type_id: TFT_DATASET
# (RayTrainWorker pid=4551, ip=128.55.66.148)     args {
# (RayTrainWorker pid=4551, ip=128.55.66.148)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=4551, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4551, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4551, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4551, ip=128.55.66.148)           type_id: TFT_FLOAT
# (RayTrainWorker pid=4551, ip=128.55.66.148)         }
# (RayTrainWorker pid=4551, ip=128.55.66.148)       }
# (RayTrainWorker pid=4551, ip=128.55.66.148)       args {
# (RayTrainWorker pid=4551, ip=128.55.66.148)         type_id: TFT_TENSOR
# (RayTrainWorker pid=4551, ip=128.55.66.148)         args {
# (RayTrainWorker pid=4551, ip=128.55.66.148)           type_id: TFT_INT64
# (RayTrainWorker pid=4551, ip=128.55.66.148)         }
# (RayTrainWorker pid=4551, ip=128.55.66.148)       }
# (RayTrainWorker pid=4551, ip=128.55.66.148)     }
# (RayTrainWorker pid=4551, ip=128.55.66.148)   }
# (RayTrainWorker pid=4551, ip=128.55.66.148) }
# (RayTrainWorker pid=4551, ip=128.55.66.148)
# (RayTrainWorker pid=77897) 2023-03-03 19:35:22.924510: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=77897) op: "TensorSliceDataset"
# (RayTrainWorker pid=77897) input: "Placeholder/_0"
# (RayTrainWorker pid=77897) input: "Placeholder/_1"
# (RayTrainWorker pid=77897) attr {
# (RayTrainWorker pid=77897)   key: "Toutput_types"
# (RayTrainWorker pid=77897)   value {
# (RayTrainWorker pid=77897)     list {
# (RayTrainWorker pid=77897)       type: DT_FLOAT
# (RayTrainWorker pid=77897)       type: DT_INT64
# (RayTrainWorker pid=77897)     }
# (RayTrainWorker pid=77897)   }
# (RayTrainWorker pid=77897) }
# (RayTrainWorker pid=77897) attr {
# (RayTrainWorker pid=77897)   key: "_cardinality"
# (RayTrainWorker pid=77897)   value {
# (RayTrainWorker pid=77897)     i: 60000
# (RayTrainWorker pid=77897)   }
# (RayTrainWorker pid=77897) }
# (RayTrainWorker pid=77897) attr {
# (RayTrainWorker pid=77897)   key: "is_files"
# (RayTrainWorker pid=77897)   value {
# (RayTrainWorker pid=77897)     b: false
# (RayTrainWorker pid=77897)   }
# (RayTrainWorker pid=77897) }
# (RayTrainWorker pid=77897) attr {
# (RayTrainWorker pid=77897)   key: "metadata"
# (RayTrainWorker pid=77897)   value {
# (RayTrainWorker pid=77897)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=77897)   }
# (RayTrainWorker pid=77897) }
# (RayTrainWorker pid=77897) attr {
# (RayTrainWorker pid=77897)   key: "output_shapes"
# (RayTrainWorker pid=77897)   value {
# (RayTrainWorker pid=77897)     list {
# (RayTrainWorker pid=77897)       shape {
# (RayTrainWorker pid=77897)         dim {
# (RayTrainWorker pid=77897)           size: 28
# (RayTrainWorker pid=77897)         }
# (RayTrainWorker pid=77897)         dim {
# (RayTrainWorker pid=77897)           size: 28
# (RayTrainWorker pid=77897)         }
# (RayTrainWorker pid=77897)       }
# (RayTrainWorker pid=77897)       shape {
# (RayTrainWorker pid=77897)       }
# (RayTrainWorker pid=77897)     }
# (RayTrainWorker pid=77897)   }
# (RayTrainWorker pid=77897) }
# (RayTrainWorker pid=77897) experimental_type {
# (RayTrainWorker pid=77897)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=77897)   args {
# (RayTrainWorker pid=77897)     type_id: TFT_DATASET
# (RayTrainWorker pid=77897)     args {
# (RayTrainWorker pid=77897)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=77897)       args {
# (RayTrainWorker pid=77897)         type_id: TFT_TENSOR
# (RayTrainWorker pid=77897)         args {
# (RayTrainWorker pid=77897)           type_id: TFT_FLOAT
# (RayTrainWorker pid=77897)         }
# (RayTrainWorker pid=77897)       }
# (RayTrainWorker pid=77897)       args {
# (RayTrainWorker pid=77897)         type_id: TFT_TENSOR
# (RayTrainWorker pid=77897)         args {
# (RayTrainWorker pid=77897)           type_id: TFT_INT64
# (RayTrainWorker pid=77897)         }
# (RayTrainWorker pid=77897)       }
# (RayTrainWorker pid=77897)     }
# (RayTrainWorker pid=77897)   }
# (RayTrainWorker pid=77897) }
# (RayTrainWorker pid=77897)
# (RayTrainWorker pid=77896) 2023-03-03 19:35:22.924494: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=77896) op: "TensorSliceDataset"
# (RayTrainWorker pid=77896) input: "Placeholder/_0"
# (RayTrainWorker pid=77896) input: "Placeholder/_1"
# (RayTrainWorker pid=77896) attr {
# (RayTrainWorker pid=77896)   key: "Toutput_types"
# (RayTrainWorker pid=77896)   value {
# (RayTrainWorker pid=77896)     list {
# (RayTrainWorker pid=77896)       type: DT_FLOAT
# (RayTrainWorker pid=77896)       type: DT_INT64
# (RayTrainWorker pid=77896)     }
# (RayTrainWorker pid=77896)   }
# (RayTrainWorker pid=77896) }
# (RayTrainWorker pid=77896) attr {
# (RayTrainWorker pid=77896)   key: "_cardinality"
# (RayTrainWorker pid=77896)   value {
# (RayTrainWorker pid=77896)     i: 60000
# (RayTrainWorker pid=77896)   }
# (RayTrainWorker pid=77896) }
# (RayTrainWorker pid=77896) attr {
# (RayTrainWorker pid=77896)   key: "is_files"
# (RayTrainWorker pid=77896)   value {
# (RayTrainWorker pid=77896)     b: false
# (RayTrainWorker pid=77896)   }
# (RayTrainWorker pid=77896) }
# (RayTrainWorker pid=77896) attr {
# (RayTrainWorker pid=77896)   key: "metadata"
# (RayTrainWorker pid=77896)   value {
# (RayTrainWorker pid=77896)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=77896)   }
# (RayTrainWorker pid=77896) }
# (RayTrainWorker pid=77896) attr {
# (RayTrainWorker pid=77896)   key: "output_shapes"
# (RayTrainWorker pid=77896)   value {
# (RayTrainWorker pid=77896)     list {
# (RayTrainWorker pid=77896)       shape {
# (RayTrainWorker pid=77896)         dim {
# (RayTrainWorker pid=77896)           size: 28
# (RayTrainWorker pid=77896)         }
# (RayTrainWorker pid=77896)         dim {
# (RayTrainWorker pid=77896)           size: 28
# (RayTrainWorker pid=77896)         }
# (RayTrainWorker pid=77896)       }
# (RayTrainWorker pid=77896)       shape {
# (RayTrainWorker pid=77896)       }
# (RayTrainWorker pid=77896)     }
# (RayTrainWorker pid=77896)   }
# (RayTrainWorker pid=77896) }
# (RayTrainWorker pid=77896) experimental_type {
# (RayTrainWorker pid=77896)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=77896)   args {
# (RayTrainWorker pid=77896)     type_id: TFT_DATASET
# (RayTrainWorker pid=77896)     args {
# (RayTrainWorker pid=77896)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=77896)       args {
# (RayTrainWorker pid=77896)         type_id: TFT_TENSOR
# (RayTrainWorker pid=77896)         args {
# (RayTrainWorker pid=77896)           type_id: TFT_FLOAT
# (RayTrainWorker pid=77896)         }
# (RayTrainWorker pid=77896)       }
# (RayTrainWorker pid=77896)       args {
# (RayTrainWorker pid=77896)         type_id: TFT_TENSOR
# (RayTrainWorker pid=77896)         args {
# (RayTrainWorker pid=77896)           type_id: TFT_INT64
# (RayTrainWorker pid=77896)         }
# (RayTrainWorker pid=77896)       }
# (RayTrainWorker pid=77896)     }
# (RayTrainWorker pid=77896)   }
# (RayTrainWorker pid=77896) }
# (RayTrainWorker pid=77896)
# (RayTrainWorker pid=77894) 2023-03-03 19:35:22.924566: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=77894) op: "TensorSliceDataset"
# (RayTrainWorker pid=77894) input: "Placeholder/_0"
# (RayTrainWorker pid=77894) input: "Placeholder/_1"
# (RayTrainWorker pid=77894) attr {
# (RayTrainWorker pid=77894)   key: "Toutput_types"
# (RayTrainWorker pid=77894)   value {
# (RayTrainWorker pid=77894)     list {
# (RayTrainWorker pid=77894)       type: DT_FLOAT
# (RayTrainWorker pid=77894)       type: DT_INT64
# (RayTrainWorker pid=77894)     }
# (RayTrainWorker pid=77894)   }
# (RayTrainWorker pid=77894) }
# (RayTrainWorker pid=77894) attr {
# (RayTrainWorker pid=77894)   key: "_cardinality"
# (RayTrainWorker pid=77894)   value {
# (RayTrainWorker pid=77894)     i: 60000
# (RayTrainWorker pid=77894)   }
# (RayTrainWorker pid=77894) }
# (RayTrainWorker pid=77894) attr {
# (RayTrainWorker pid=77894)   key: "is_files"
# (RayTrainWorker pid=77894)   value {
# (RayTrainWorker pid=77894)     b: false
# (RayTrainWorker pid=77894)   }
# (RayTrainWorker pid=77894) }
# (RayTrainWorker pid=77894) attr {
# (RayTrainWorker pid=77894)   key: "metadata"
# (RayTrainWorker pid=77894)   value {
# (RayTrainWorker pid=77894)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=77894)   }
# (RayTrainWorker pid=77894) }
# (RayTrainWorker pid=77894) attr {
# (RayTrainWorker pid=77894)   key: "output_shapes"
# (RayTrainWorker pid=77894)   value {
# (RayTrainWorker pid=77894)     list {
# (RayTrainWorker pid=77894)       shape {
# (RayTrainWorker pid=77894)         dim {
# (RayTrainWorker pid=77894)           size: 28
# (RayTrainWorker pid=77894)         }
# (RayTrainWorker pid=77894)         dim {
# (RayTrainWorker pid=77894)           size: 28
# (RayTrainWorker pid=77894)         }
# (RayTrainWorker pid=77894)       }
# (RayTrainWorker pid=77894)       shape {
# (RayTrainWorker pid=77894)       }
# (RayTrainWorker pid=77894)     }
# (RayTrainWorker pid=77894)   }
# (RayTrainWorker pid=77894) }
# (RayTrainWorker pid=77894) experimental_type {
# (RayTrainWorker pid=77894)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=77894)   args {
# (RayTrainWorker pid=77894)     type_id: TFT_DATASET
# (RayTrainWorker pid=77894)     args {
# (RayTrainWorker pid=77894)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=77894)       args {
# (RayTrainWorker pid=77894)         type_id: TFT_TENSOR
# (RayTrainWorker pid=77894)         args {
# (RayTrainWorker pid=77894)           type_id: TFT_FLOAT
# (RayTrainWorker pid=77894)         }
# (RayTrainWorker pid=77894)       }
# (RayTrainWorker pid=77894)       args {
# (RayTrainWorker pid=77894)         type_id: TFT_TENSOR
# (RayTrainWorker pid=77894)         args {
# (RayTrainWorker pid=77894)           type_id: TFT_INT64
# (RayTrainWorker pid=77894)         }
# (RayTrainWorker pid=77894)       }
# (RayTrainWorker pid=77894)     }
# (RayTrainWorker pid=77894)   }
# (RayTrainWorker pid=77894) }
# (RayTrainWorker pid=77894)
# (RayTrainWorker pid=77895) 2023-03-03 19:35:22.924498: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (RayTrainWorker pid=77895) op: "TensorSliceDataset"
# (RayTrainWorker pid=77895) input: "Placeholder/_0"
# (RayTrainWorker pid=77895) input: "Placeholder/_1"
# (RayTrainWorker pid=77895) attr {
# (RayTrainWorker pid=77895)   key: "Toutput_types"
# (RayTrainWorker pid=77895)   value {
# (RayTrainWorker pid=77895)     list {
# (RayTrainWorker pid=77895)       type: DT_FLOAT
# (RayTrainWorker pid=77895)       type: DT_INT64
# (RayTrainWorker pid=77895)     }
# (RayTrainWorker pid=77895)   }
# (RayTrainWorker pid=77895) }
# (RayTrainWorker pid=77895) attr {
# (RayTrainWorker pid=77895)   key: "_cardinality"
# (RayTrainWorker pid=77895)   value {
# (RayTrainWorker pid=77895)     i: 60000
# (RayTrainWorker pid=77895)   }
# (RayTrainWorker pid=77895) }
# (RayTrainWorker pid=77895) attr {
# (RayTrainWorker pid=77895)   key: "is_files"
# (RayTrainWorker pid=77895)   value {
# (RayTrainWorker pid=77895)     b: false
# (RayTrainWorker pid=77895)   }
# (RayTrainWorker pid=77895) }
# (RayTrainWorker pid=77895) attr {
# (RayTrainWorker pid=77895)   key: "metadata"
# (RayTrainWorker pid=77895)   value {
# (RayTrainWorker pid=77895)     s: "\n\024TensorSliceDataset:0"
# (RayTrainWorker pid=77895)   }
# (RayTrainWorker pid=77895) }
# (RayTrainWorker pid=77895) attr {
# (RayTrainWorker pid=77895)   key: "output_shapes"
# (RayTrainWorker pid=77895)   value {
# (RayTrainWorker pid=77895)     list {
# (RayTrainWorker pid=77895)       shape {
# (RayTrainWorker pid=77895)         dim {
# (RayTrainWorker pid=77895)           size: 28
# (RayTrainWorker pid=77895)         }
# (RayTrainWorker pid=77895)         dim {
# (RayTrainWorker pid=77895)           size: 28
# (RayTrainWorker pid=77895)         }
# (RayTrainWorker pid=77895)       }
# (RayTrainWorker pid=77895)       shape {
# (RayTrainWorker pid=77895)       }
# (RayTrainWorker pid=77895)     }
# (RayTrainWorker pid=77895)   }
# (RayTrainWorker pid=77895) }
# (RayTrainWorker pid=77895) experimental_type {
# (RayTrainWorker pid=77895)   type_id: TFT_PRODUCT
# (RayTrainWorker pid=77895)   args {
# (RayTrainWorker pid=77895)     type_id: TFT_DATASET
# (RayTrainWorker pid=77895)     args {
# (RayTrainWorker pid=77895)       type_id: TFT_PRODUCT
# (RayTrainWorker pid=77895)       args {
# (RayTrainWorker pid=77895)         type_id: TFT_TENSOR
# (RayTrainWorker pid=
# (TunerInternal pid=77000)   node_ip: 128.55.66.148
# (TunerInternal pid=77000)   pid: 8644
# (TunerInternal pid=77000)   should_checkpoint: true
# (TunerInternal pid=77000)   time_since_restore: 18.169158458709717
# (TunerInternal pid=77000)   time_this_iter_s: 2.057485342025757
# (TunerInternal pid=77000)   time_total_s: 18.169158458709717
# (TunerInternal pid=77000)   timestamp: 1677900960
# (TunerInternal pid=77000)   timesteps_since_restore: 0
# (TunerInternal pid=77000)   training_iteration: 3
# (TunerInternal pid=77000)   trial_id: 8f7c2_00001
# (TunerInternal pid=77000)   warmup_time: 0.018320560455322266
# (TunerInternal pid=77000)
# (TunerInternal pid=77000) Trial TensorflowTrainer_8f7c2_00001 completed.
# (RayTrainWorker pid=82924) Exception ignored in: <function Pool.__del__ at 0x145a2c069790>
# (RayTrainWorker pid=82924) Traceback (most recent call last):
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/pool.py", line 268, in __del__
# (RayTrainWorker pid=82924)     self._change_notifier.put(None)
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/queues.py", line 377, in put
# (RayTrainWorker pid=82924)     self._writer.send_bytes(obj)
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/connection.py", line 205, in send_bytes
# (RayTrainWorker pid=82924)     self._send_bytes(m[offset:offset + size])
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/connection.py", line 416, in _send_bytes
# (RayTrainWorker pid=82924)     self._send(header + buf)
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/connection.py", line 373, in _send
# (RayTrainWorker pid=82924)     n = write(self._handle, buf)
# (RayTrainWorker pid=82924) OSError: [Errno 9] Bad file descriptor
# (RayTrainWorker pid=82924) Exception ignored in: <function Pool.__del__ at 0x145a2c069790>
# (RayTrainWorker pid=82924) Traceback (most recent call last):
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/pool.py", line 268, in __del__
# (RayTrainWorker pid=82924)     self._change_notifier.put(None)
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/queues.py", line 377, in put
# (RayTrainWorker pid=82924)     self._writer.send_bytes(obj)
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/connection.py", line 205, in send_bytes
# (RayTrainWorker pid=82924)     self._send_bytes(m[offset:offset + size])
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/connection.py", line 416, in _send_bytes
# (RayTrainWorker pid=82924)     self._send(header + buf)
# (RayTrainWorker pid=82924)   File "/global/common/software/nersc/pm-2022q4/sw/tensorflow/2.9.0/lib/python3.9/multiprocessing/connection.py", line 373, in _send
# (RayTrainWorker pid=82924)     n = write(self._handle, buf)
# (RayTrainWorker pid=82924) OSError: [Errno 9] Bad file descriptor
# Best accuracy config: 0.6419363617897034
# (TunerInternal pid=77000) 2023-03-03 19:36:04,602	INFO tune.py:798 -- Total run time: 56.46 seconds (56.40 seconds for the tuning loop).

# %%
log_dir = str(results.get_best_result().log_dir)

# %% [markdown]
# ## Close cluster conection and stop job

# %%
ray.shutdown()

# %%
sfp_api.delete_job(site, job['jobid'])
# Out:
# {'task_id': '0', 'status': 'OK', 'error': None}

# %% [markdown]
# ## Explore Training in Tensorboard

# %%
import nersc_tensorboard_helper
# %load_ext tensorboard

# %%
# %tensorboard --logdir $log_dir --port 0
# Out:
#       <iframe id="tensorboard-frame-d582d9fa15d15500" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d582d9fa15d15500");
#           const url = new URL("/", window.location);
#           const port = 44279;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
nersc_tensorboard_helper.tb_address()
# Out:
# <a href="https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/44279/">https://jupyter.nersc.gov/user/asnaylor/perlmutter-shared-node-cpu/proxy/44279/</a>
